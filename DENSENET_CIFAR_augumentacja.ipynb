# %%
import os
import pandas as pd


import torch
import torch.nn as nn
import torch.optim as optim


import torchvision
import torchvision.transforms as transforms
from torch.utils.data import ConcatDataset

from torchvision.models import densenet121
from torch.utils.data import DataLoader, random_split


print(torch.__version__)
print(torch.version.cuda)
print(torch.backends.cudnn.enabled)
# Out:
# 2.2.0+cu121
# 12.1
# True

# %%
#KONIGURaCJa
# dataset:
# "CIFAR10"
# "CIFAR100"
DATASET_NAME = "CIFAR100"


BATCH_SIZE = 80
EPOCHS = 30
LEARNING_RATE = 0.08


MODEL_SAVE_PATH_CHECKPOINT = f"models/t_checkpoint_augumentacja_densenet_{DATASET_NAME.lower()}_{BATCH_SIZE}batch_{EPOCHS}epochs_{LEARNING_RATE}lr.pth"
MODEL_SAVE_PATH = f"models/densenet_model_augumentacja_{DATASET_NAME.lower()}_{BATCH_SIZE}batch_{EPOCHS}epochs_{LEARNING_RATE}lr.pth"
RESULTS_TO_EXCEL = "training_results_DENSENET_CIFAR_augumentacja.xlsx"
# EARLY STOPPING
PATIENCE = 5

# %%
#device
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print("======================================")
print("DEVICE:", device)
print("======================================")
# Out:
# ======================================
# DEVICE: cuda
# ======================================

# %%
# TRANSFORMACJE

# Oryginalne dane
transform_base = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(
        (0.4914, 0.4822, 0.4465),
        (0.2023, 0.1994, 0.2010)
    )
])

# Augmentacja nr 1
transform_aug1 = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32, padding=4),
    transforms.RandomRotation(15),
    transforms.ToTensor(),
    transforms.Normalize(
        (0.4914, 0.4822, 0.4465),
        (0.2023, 0.1994, 0.2010)
    )
])
# Augmentacja nr 2
transform_aug2 = transforms.Compose([
    transforms.ColorJitter(
        brightness=0.2,
        contrast=0.2,
        saturation=0.2
    ),
    transforms.RandomAffine(
        degrees=20,
        translate=(0.1, 0.1)
    ),
    transforms.ToTensor(),
    transforms.Normalize(
        (0.4914, 0.4822, 0.4465),
        (0.2023, 0.1994, 0.2010)
    )
])

# Test bez augmentacji
transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(
        (0.4914, 0.4822, 0.4465),
        (0.2023, 0.1994, 0.2010)
    )
])

# %%
# ============================================================
# DATASET
# ============================================================

if DATASET_NAME == "CIFAR10":

    NUM_CLASSES = 10

    # ORYGINALNY DATASET
    dataset_original = torchvision.datasets.CIFAR10(
        root="./data",
        train=True,
        download=True,
        transform=transform_base
    )

    # AUGMENTOWANA KOPIA 1
    dataset_aug1 = torchvision.datasets.CIFAR10(
        root="./data",
        train=True,
        download=True,
        transform=transform_aug1
    )

    # AUGMENTOWANA KOPIA 2
    dataset_aug2 = torchvision.datasets.CIFAR10(
        root="./data",
        train=True,
        download=True,
        transform=transform_aug2
    )

    # POŁĄCZENIE DATASETÓW
    full_train_dataset = ConcatDataset([
        dataset_original,
        dataset_aug1,
        dataset_aug2
    ])
    test_dataset = torchvision.datasets.CIFAR10(
        root="./data",
        train=False,
        download=True,
        transform=transform_test
    )

elif DATASET_NAME == "CIFAR100":

    NUM_CLASSES = 100

    dataset_original = torchvision.datasets.CIFAR100(
        root="./data",
        train=True,
        download=True,
        transform=transform_base
    )
    dataset_aug1 = torchvision.datasets.CIFAR100(
        root="./data",
        train=True,
        download=True,
        transform=transform_aug1
    )

    dataset_aug2 = torchvision.datasets.CIFAR100(
        root="./data",
        train=True,
        download=True,
        transform=transform_aug2
    )

    full_train_dataset = ConcatDataset([
        dataset_original,
        dataset_aug1,
        dataset_aug2
    ])

    test_dataset = torchvision.datasets.CIFAR100(
        root="./data",
        train=False,
        download=True,
        transform=transform_test
    )

else:
    raise ValueError("DATASET_NAME musi być CIFAR10 albo CIFAR100")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# ============================================================
# PODZIAŁ TRAIN / VALIDATION
# ============================================================

train_size = int(0.8 * len(full_train_dataset))
val_size = len(full_train_dataset) - train_size

train_dataset, val_dataset = random_split(
    full_train_dataset,
    [train_size, val_size]
)

# %%
# DATALOADER
train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=0,
    pin_memory=torch.cuda.is_available()
)

val_loader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=0,
    pin_memory=torch.cuda.is_available()
)

test_loader = DataLoader(
    test_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=0,
    pin_memory=torch.cuda.is_available()
)

# %%
# MODEL DENSENET121


# weights=None -> brak pretrained weights
model = densenet121(weights=None)

# zmiana pierwszej warstwy dla CIFAR
model.features.conv0 = nn.Conv2d(
    3, #licza kanałów wejściowych (RGB)
    64, # liczba kanałów wyjściowych (zgodna z oryginalnym modelem)
    kernel_size=3,# rozmiar filtra
    stride=1, #krok przesuwania filtra
    padding=1,#dodanie paddingu, żeby zachować rozmiar obrazu bo filtr 3x3 nie miesci sie
    bias=False
)

# usunięcie maxpool
model.features.pool0 = nn.Identity()

# zmiana klasyfikatora
model.classifier = nn.Sequential(
    nn.Dropout(0.3),
    nn.Linear(  
    model.classifier.in_features,
    NUM_CLASSES)
)

model = model.to(device)

print("======================================")
print(model)
print("======================================")
# Out:
# ======================================
# DenseNet(
#   (features): Sequential(
#     (conv0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu0): ReLU(inplace=True)
#     (pool0): Identity()
#     (denseblock1): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition1): _Transition(
#       (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock2): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition2): _Transition(
#       (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock3): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer17): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer18): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer19): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer20): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer21): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer22): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer23): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer24): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition3): _Transition(
#       (norm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock4): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (norm5): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.3, inplace=False)
#     (1): Linear(in_features=1024, out_features=100, bias=True)
#   )
# )
# ======================================

# %%
# LOSS + OPTIMIZER


criterion = nn.CrossEntropyLoss(
    label_smoothing=0.1
)
# optimizer = optim.SGD(
#     model.parameters(),
#     lr=LEARNING_RATE,
#     momentum=0.9,
#     weight_decay=5e-4
# )
# optimizer = optim.Adam(
#     model.parameters(),
#     lr=LEARNING_RATE
# )
optimizer = optim.SGD(
    model.parameters(),
    lr=LEARNING_RATE,
    momentum=0.9,
    weight_decay=5e-4,
    nesterov=True
    
)
# optimizer = optim.AdamW(
#     model.parameters(),
#     lr=1e-4,
#     weight_decay=0.05
# )
# scheduler = optim.lr_scheduler.StepLR(
#     optimizer,
#     step_size=5,
#     gamma=0.1
# )


scheduler = optim.lr_scheduler.CosineAnnealingLR(
    optimizer,
    T_max=EPOCHS
)

# %%
# ============================================================
# EARLY STOPPING VARIABLES
# ============================================================

best_val_loss = float("inf")
early_stop_counter = 0

# %%
#pętla treningowa


print("======================================")
print("START TRENINGU")
print("======================================")

for epoch in range(EPOCHS):

    model.train()

    running_loss = 0.0
    correct_train = 0
    total_train = 0

    for batch_idx, (images, labels) in enumerate(train_loader):

        images = images.to(device)
        labels = labels.to(device)

        # zerowanie gradientów
        optimizer.zero_grad()

        # forward
        outputs = model(images)

        # loss
        loss = criterion(outputs, labels)

        # backward
        loss.backward() #liczenie gradientow

        # update wag
        optimizer.step()

        running_loss += loss.item()
        
        # accuracy train
        _, predicted = torch.max(outputs , 1)

        total_train += labels.size(0)

        correct_train += (predicted == labels).sum().item()
        
        # ====================================================
        # BATCH LOGGING
        # ====================================================

        if (batch_idx + 1) % 100 == 0:

            print(
                f"Epoch [{epoch+1}/{EPOCHS}] | "
                f"Batch [{batch_idx+1}/{len(train_loader)}] | "
                f"Batch Loss: {loss.item():.4f}"
            )

        
    # ========================================================
    # TRAIN METRICS
    # ========================================================

    train_loss = running_loss / len(train_loader)

    train_accuracy = 100 * correct_train / total_train
        
    # ========================================================
    # VALIDATION
    # ========================================================

    model.eval()

    running_val_loss = 0.0

    correct = 0
    total = 0

    with torch.no_grad():

        for images, labels in val_loader:

            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)

            loss = criterion(outputs, labels)

            running_val_loss += loss.item()

            _, predicted = torch.max(outputs, 1)

            total += labels.size(0)

            correct += (predicted == labels).sum().item()

    # ========================================================
    # VALIDATION METRICS
    # ========================================================

    val_loss = running_val_loss / len(val_loader)

    val_accuracy = 100 * correct / total

    # ========================================================
    # SCHEDULER STEP
    # ========================================================

    scheduler.step()
        

    # ========================================================
    # EPOCH LOGGING
    # ========================================================

    current_lr = optimizer.param_groups[0]["lr"]

    print("======================================")
    print(f"Epoch [{epoch+1}/{EPOCHS}] zakończona")
    print(f"Train Loss     : {train_loss:.4f}")
    print(f"Train Accuracy : {train_accuracy:.2f}%")
    print(f"Val Loss       : {val_loss:.4f}")
    print(f"Val Accuracy   : {val_accuracy:.2f}%")
    print(f"Learning Rate  : {current_lr}")
    print("======================================")

    # ========================================================
    # EARLY STOPPING
    # ========================================================

    if val_loss < best_val_loss:

        best_val_loss = val_loss
        early_stop_counter = 0

        torch.save(model.state_dict(), MODEL_SAVE_PATH)

        print("Najlepszy model zapisany.")

    else:

        early_stop_counter += 1

        print(f"Brak poprawy. Counter: {early_stop_counter}/{PATIENCE}")

    if early_stop_counter >= PATIENCE:

        print("======================================")
        print("EARLY STOPPING")
        print("======================================")
        break

print("======================================")
print("KONIEC TRENINGU")
print("======================================")

# ============================================================
# WCZYTANIE NAJLEPSZEGO MODELU
# ============================================================

model.load_state_dict(torch.load(MODEL_SAVE_PATH))
model.to(device)
# Out:
# ======================================
# START TRENINGU
# ======================================
# Epoch [1/30] | Batch [100/1500] | Batch Loss: 4.3718
# Epoch [1/30] | Batch [200/1500] | Batch Loss: 4.0898
# Epoch [1/30] | Batch [300/1500] | Batch Loss: 3.9804
# Epoch [1/30] | Batch [400/1500] | Batch Loss: 3.5873
# Epoch [1/30] | Batch [500/1500] | Batch Loss: 3.7547
# Epoch [1/30] | Batch [600/1500] | Batch Loss: 3.6543
# Epoch [1/30] | Batch [700/1500] | Batch Loss: 3.4656
# Epoch [1/30] | Batch [800/1500] | Batch Loss: 3.4141
# Epoch [1/30] | Batch [900/1500] | Batch Loss: 3.3397
# Epoch [1/30] | Batch [1000/1500] | Batch Loss: 3.5389
# Epoch [1/30] | Batch [1100/1500] | Batch Loss: 3.4967
# Epoch [1/30] | Batch [1200/1500] | Batch Loss: 3.2427
# Epoch [1/30] | Batch [1300/1500] | Batch Loss: 3.0028
# Epoch [1/30] | Batch [1400/1500] | Batch Loss: 2.9064
# Epoch [1/30] | Batch [1500/1500] | Batch Loss: 2.9320
# ======================================
# Epoch [1/30] zakończona
# Train Loss     : 3.5822
# Train Accuracy : 19.57%
# Val Loss       : 3.0401
# Val Accuracy   : 31.13%
# Learning Rate  : 0.07978087581473094
# ======================================
# Najlepszy model zapisany.
# Epoch [2/30] | Batch [100/1500] | Batch Loss: 2.6555
# Epoch [2/30] | Batch [200/1500] | Batch Loss: 2.7881
# Epoch [2/30] | Batch [300/1500] | Batch Loss: 2.9749
# Epoch [2/30] | Batch [400/1500] | Batch Loss: 2.7580
# Epoch [2/30] | Batch [500/1500] | Batch Loss: 2.6332
# Epoch [2/30] | Batch [600/1500] | Batch Loss: 2.7306
# Epoch [2/30] | Batch [700/1500] | Batch Loss: 2.8013
# Epoch [2/30] | Batch [800/1500] | Batch Loss: 2.5893
# Epoch [2/30] | Batch [900/1500] | Batch Loss: 2.8434
# Epoch [2/30] | Batch [1000/1500] | Batch Loss: 2.3948
# Epoch [2/30] | Batch [1100/1500] | Batch Loss: 2.5534
# Epoch [2/30] | Batch [1200/1500] | Batch Loss: 2.2975
# Epoch [2/30] | Batch [1300/1500] | Batch Loss: 2.6209
# Epoch [2/30] | Batch [1400/1500] | Batch Loss: 2.5131
# Epoch [2/30] | Batch [1500/1500] | Batch Loss: 2.3588
# ======================================
# Epoch [2/30] zakończona
# Train Loss     : 2.6740
# Train Accuracy : 41.59%
# Val Loss       : 2.5500
# Val Accuracy   : 45.18%
# Learning Rate  : 0.07912590402935223
# ======================================
# Najlepszy model zapisany.
# Epoch [3/30] | Batch [100/1500] | Batch Loss: 2.4611
# Epoch [3/30] | Batch [200/1500] | Batch Loss: 2.5441
# Epoch [3/30] | Batch [300/1500] | Batch Loss: 2.3257
# Epoch [3/30] | Batch [400/1500] | Batch Loss: 2.4317
# Epoch [3/30] | Batch [500/1500] | Batch Loss: 2.3159
# Epoch [3/30] | Batch [600/1500] | Batch Loss: 2.4697
# Epoch [3/30] | Batch [700/1500] | Batch Loss: 2.3574
# Epoch [3/30] | Batch [800/1500] | Batch Loss: 2.4100
# Epoch [3/30] | Batch [900/1500] | Batch Loss: 2.2218
# Epoch [3/30] | Batch [1000/1500] | Batch Loss: 2.4408
# Epoch [3/30] | Batch [1100/1500] | Batch Loss: 2.3669
# Epoch [3/30] | Batch [1200/1500] | Batch Loss: 2.1856
# Epoch [3/30] | Batch [1300/1500] | Batch Loss: 2.2758
# Epoch [3/30] | Batch [1400/1500] | Batch Loss: 2.2830
# Epoch [3/30] | Batch [1500/1500] | Batch Loss: 2.2107
# ======================================
# Epoch [3/30] zakończona
# Train Loss     : 2.3346
# Train Accuracy : 51.21%
# Val Loss       : 2.3369
# Val Accuracy   : 51.22%
# Learning Rate  : 0.07804226065180615
# ======================================
# Najlepszy model zapisany.
# Epoch [4/30] | Batch [100/1500] | Batch Loss: 2.3555
# Epoch [4/30] | Batch [200/1500] | Batch Loss: 2.4013
# Epoch [4/30] | Batch [300/1500] | Batch Loss: 2.1937
# Epoch [4/30] | Batch [400/1500] | Batch Loss: 2.2737
# Epoch [4/30] | Batch [500/1500] | Batch Loss: 2.3539
# Epoch [4/30] | Batch [600/1500] | Batch Loss: 2.2649
# Epoch [4/30] | Batch [700/1500] | Batch Loss: 2.2917
# Epoch [4/30] | Batch [800/1500] | Batch Loss: 2.4090
# Epoch [4/30] | Batch [900/1500] | Batch Loss: 2.0241
# Epoch [4/30] | Batch [1000/1500] | Batch Loss: 2.2731
# Epoch [4/30] | Batch [1100/1500] | Batch Loss: 2.2201
# Epoch [4/30] | Batch [1200/1500] | Batch Loss: 2.1474
# Epoch [4/30] | Batch [1300/1500] | Batch Loss: 1.9593
# Epoch [4/30] | Batch [1400/1500] | Batch Loss: 2.2514
# Epoch [4/30] | Batch [1500/1500] | Batch Loss: 2.2377
# ======================================
# Epoch [4/30] zakończona
# Train Loss     : 2.1977
# Train Accuracy : 55.37%
# Val Loss       : 2.3706
# Val Accuracy   : 49.90%
# Learning Rate  : 0.07654181830570403
# ======================================
# Brak poprawy. Counter: 1/5
# Epoch [5/30] | Batch [100/1500] | Batch Loss: 2.0850
# Epoch [5/30] | Batch [200/1500] | Batch Loss: 2.2196
# Epoch [5/30] | Batch [300/1500] | Batch Loss: 2.0649
# Epoch [5/30] | Batch [400/1500] | Batch Loss: 2.2467
# Epoch [5/30] | Batch [500/1500] | Batch Loss: 2.1621
# Epoch [5/30] | Batch [600/1500] | Batch Loss: 2.3815
# Epoch [5/30] | Batch [700/1500] | Batch Loss: 2.3225
# Epoch [5/30] | Batch [800/1500] | Batch Loss: 2.1047
# Epoch [5/30] | Batch [900/1500] | Batch Loss: 2.0454
# Epoch [5/30] | Batch [1000/1500] | Batch Loss: 1.9987
# Epoch [5/30] | Batch [1100/1500] | Batch Loss: 2.0230
# Epoch [5/30] | Batch [1200/1500] | Batch Loss: 2.3600
# Epoch [5/30] | Batch [1300/1500] | Batch Loss: 2.0844
# Epoch [5/30] | Batch [1400/1500] | Batch Loss: 2.0407
# Epoch [5/30] | Batch [1500/1500] | Batch Loss: 2.0945
# ======================================
# Epoch [5/30] zakończona
# Train Loss     : 2.1220
# Train Accuracy : 57.66%
# Val Loss       : 2.3512
# Val Accuracy   : 51.64%
# Learning Rate  : 0.07464101615137755
# ======================================
# Brak poprawy. Counter: 2/5
# Epoch [6/30] | Batch [100/1500] | Batch Loss: 1.8729
# Epoch [6/30] | Batch [200/1500] | Batch Loss: 1.9785
# Epoch [6/30] | Batch [300/1500] | Batch Loss: 1.9748
# Epoch [6/30] | Batch [400/1500] | Batch Loss: 2.0789
# Epoch [6/30] | Batch [500/1500] | Batch Loss: 2.1827
# Epoch [6/30] | Batch [600/1500] | Batch Loss: 2.1672
# Epoch [6/30] | Batch [700/1500] | Batch Loss: 2.0114
# Epoch [6/30] | Batch [800/1500] | Batch Loss: 1.9851
# Epoch [6/30] | Batch [900/1500] | Batch Loss: 1.9161
# Epoch [6/30] | Batch [1000/1500] | Batch Loss: 2.3102
# Epoch [6/30] | Batch [1100/1500] | Batch Loss: 1.8191
# Epoch [6/30] | Batch [1200/1500] | Batch Loss: 1.9376
# Epoch [6/30] | Batch [1300/1500] | Batch Loss: 2.0466
# Epoch [6/30] | Batch [1400/1500] | Batch Loss: 2.0776
# Epoch [6/30] | Batch [1500/1500] | Batch Loss: 2.1588
# ======================================
# Epoch [6/30] zakończona
# Train Loss     : 2.0599
# Train Accuracy : 59.55%
# Val Loss       : 2.3268
# Val Accuracy   : 50.56%
# Learning Rate  : 0.0723606797749979
# ======================================
# Najlepszy model zapisany.
# Epoch [7/30] | Batch [100/1500] | Batch Loss: 2.1001
# Epoch [7/30] | Batch [200/1500] | Batch Loss: 2.0923
# Epoch [7/30] | Batch [300/1500] | Batch Loss: 1.9501
# Epoch [7/30] | Batch [400/1500] | Batch Loss: 1.9420
# Epoch [7/30] | Batch [500/1500] | Batch Loss: 2.3334
# Epoch [7/30] | Batch [600/1500] | Batch Loss: 1.9279
# Epoch [7/30] | Batch [700/1500] | Batch Loss: 2.2067
# Epoch [7/30] | Batch [800/1500] | Batch Loss: 2.1180
# Epoch [7/30] | Batch [900/1500] | Batch Loss: 1.9135
# Epoch [7/30] | Batch [1000/1500] | Batch Loss: 1.9869
# Epoch [7/30] | Batch [1100/1500] | Batch Loss: 2.0609
# Epoch [7/30] | Batch [1200/1500] | Batch Loss: 1.9389
# Epoch [7/30] | Batch [1300/1500] | Batch Loss: 1.7950
# Epoch [7/30] | Batch [1400/1500] | Batch Loss: 1.8817
# Epoch [7/30] | Batch [1500/1500] | Batch Loss: 2.1304
# ======================================
# Epoch [7/30] zakończona
# Train Loss     : 2.0057
# Train Accuracy : 61.19%
# Val Loss       : 2.0709
# Val Accuracy   : 58.92%
# Learning Rate  : 0.06972579301909576
# ======================================
# Najlepszy model zapisany.
# Epoch [8/30] | Batch [100/1500] | Batch Loss: 2.0390
# Epoch [8/30] | Batch [200/1500] | Batch Loss: 2.0004
# Epoch [8/30] | Batch [300/1500] | Batch Loss: 2.1429
# Epoch [8/30] | Batch [400/1500] | Batch Loss: 1.8952
# Epoch [8/30] | Batch [500/1500] | Batch Loss: 2.1746
# Epoch [8/30] | Batch [600/1500] | Batch Loss: 1.8665
# Epoch [8/30] | Batch [700/1500] | Batch Loss: 1.9833
# Epoch [8/30] | Batch [800/1500] | Batch Loss: 2.0228
# Epoch [8/30] | Batch [900/1500] | Batch Loss: 2.0463
# Epoch [8/30] | Batch [1000/1500] | Batch Loss: 2.0195
# Epoch [8/30] | Batch [1100/1500] | Batch Loss: 1.9208
# Epoch [8/30] | Batch [1200/1500] | Batch Loss: 2.0637
# Epoch [8/30] | Batch [1300/1500] | Batch Loss: 1.8727
# Epoch [8/30] | Batch [1400/1500] | Batch Loss: 2.1394
# Epoch [8/30] | Batch [1500/1500] | Batch Loss: 2.3121
# ======================================
# Epoch [8/30] zakończona
# Train Loss     : 1.9609
# Train Accuracy : 62.66%
# Val Loss       : 2.0342
# Val Accuracy   : 59.94%
# Learning Rate  : 0.06676522425435433
# ======================================
# Najlepszy model zapisany.
# Epoch [9/30] | Batch [100/1500] | Batch Loss: 1.7677
# Epoch [9/30] | Batch [200/1500] | Batch Loss: 1.8354
# Epoch [9/30] | Batch [300/1500] | Batch Loss: 1.9476
# Epoch [9/30] | Batch [400/1500] | Batch Loss: 1.8296
# Epoch [9/30] | Batch [500/1500] | Batch Loss: 1.9335
# Epoch [9/30] | Batch [600/1500] | Batch Loss: 1.9568
# Epoch [9/30] | Batch [700/1500] | Batch Loss: 1.7898
# Epoch [9/30] | Batch [800/1500] | Batch Loss: 1.9810
# Epoch [9/30] | Batch [900/1500] | Batch Loss: 2.0483
# Epoch [9/30] | Batch [1000/1500] | Batch Loss: 2.0779
# Epoch [9/30] | Batch [1100/1500] | Batch Loss: 2.1385
# Epoch [9/30] | Batch [1200/1500] | Batch Loss: 1.9447
# Epoch [9/30] | Batch [1300/1500] | Batch Loss: 1.8136
# Epoch [9/30] | Batch [1400/1500] | Batch Loss: 1.9674
# Epoch [9/30] | Batch [1500/1500] | Batch Loss: 1.7700
# ======================================
# Epoch [9/30] zakończona
# Train Loss     : 1.9244
# Train Accuracy : 63.72%
# Val Loss       : 1.9319
# Val Accuracy   : 63.03%
# Learning Rate  : 0.06351141009169892
# ======================================
# Najlepszy model zapisany.
# Epoch [10/30] | Batch [100/1500] | Batch Loss: 1.7861
# Epoch [10/30] | Batch [200/1500] | Batch Loss: 1.8485
# Epoch [10/30] | Batch [300/1500] | Batch Loss: 1.7397
# Epoch [10/30] | Batch [400/1500] | Batch Loss: 1.6623
# Epoch [10/30] | Batch [500/1500] | Batch Loss: 1.7466
# Epoch [10/30] | Batch [600/1500] | Batch Loss: 1.8405
# Epoch [10/30] | Batch [700/1500] | Batch Loss: 1.9318
# Epoch [10/30] | Batch [800/1500] | Batch Loss: 2.0247
# Epoch [10/30] | Batch [900/1500] | Batch Loss: 1.8377
# Epoch [10/30] | Batch [1000/1500] | Batch Loss: 1.7509
# Epoch [10/30] | Batch [1100/1500] | Batch Loss: 1.9078
# Epoch [10/30] | Batch [1200/1500] | Batch Loss: 1.8562
# Epoch [10/30] | Batch [1300/1500] | Batch Loss: 1.9060
# Epoch [10/30] | Batch [1400/1500] | Batch Loss: 1.7805
# Epoch [10/30] | Batch [1500/1500] | Batch Loss: 1.7604
# ======================================
# Epoch [10/30] zakończona
# Train Loss     : 1.8830
# Train Accuracy : 64.93%
# Val Loss       : 2.1700
# Val Accuracy   : 56.61%
# Learning Rate  : 0.05999999999999999
# ======================================
# Brak poprawy. Counter: 1/5
# Epoch [11/30] | Batch [100/1500] | Batch Loss: 1.7575
# Epoch [11/30] | Batch [200/1500] | Batch Loss: 2.0451
# Epoch [11/30] | Batch [300/1500] | Batch Loss: 1.9273
# Epoch [11/30] | Batch [400/1500] | Batch Loss: 1.9327
# Epoch [11/30] | Batch [500/1500] | Batch Loss: 1.8552
# Epoch [11/30] | Batch [600/1500] | Batch Loss: 1.9939
# Epoch [11/30] | Batch [700/1500] | Batch Loss: 1.9066
# Epoch [11/30] | Batch [800/1500] | Batch Loss: 1.9552
# Epoch [11/30] | Batch [900/1500] | Batch Loss: 1.7725
# Epoch [11/30] | Batch [1000/1500] | Batch Loss: 1.9570
# Epoch [11/30] | Batch [1100/1500] | Batch Loss: 1.9281
# Epoch [11/30] | Batch [1200/1500] | Batch Loss: 1.9530
# Epoch [11/30] | Batch [1300/1500] | Batch Loss: 1.8015
# Epoch [11/30] | Batch [1400/1500] | Batch Loss: 1.7254
# Epoch [11/30] | Batch [1500/1500] | Batch Loss: 2.1664
# ======================================
# Epoch [11/30] zakończona
# Train Loss     : 1.8426
# Train Accuracy : 66.18%
# Val Loss       : 1.9234
# Val Accuracy   : 63.08%
# Learning Rate  : 0.05626946572303201
# ======================================
# Najlepszy model zapisany.
# Epoch [12/30] | Batch [100/1500] | Batch Loss: 1.8419
# Epoch [12/30] | Batch [200/1500] | Batch Loss: 2.0948
# Epoch [12/30] | Batch [300/1500] | Batch Loss: 1.8137
# Epoch [12/30] | Batch [400/1500] | Batch Loss: 1.6482
# Epoch [12/30] | Batch [500/1500] | Batch Loss: 2.0046
# Epoch [12/30] | Batch [600/1500] | Batch Loss: 1.8495
# Epoch [12/30] | Batch [700/1500] | Batch Loss: 1.9894
# Epoch [12/30] | Batch [800/1500] | Batch Loss: 1.7578
# Epoch [12/30] | Batch [900/1500] | Batch Loss: 1.9065
# Epoch [12/30] | Batch [1000/1500] | Batch Loss: 1.7979
# Epoch [12/30] | Batch [1100/1500] | Batch Loss: 1.9834
# Epoch [12/30] | Batch [1200/1500] | Batch Loss: 1.6509
# Epoch [12/30] | Batch [1300/1500] | Batch Loss: 1.8858
# Epoch [12/30] | Batch [1400/1500] | Batch Loss: 1.7253
# Epoch [12/30] | Batch [1500/1500] | Batch Loss: 2.3596
# ======================================
# Epoch [12/30] zakończona
# Train Loss     : 1.8053
# Train Accuracy : 67.43%
# Val Loss       : 1.8578
# Val Accuracy   : 65.14%
# Learning Rate  : 0.05236067977499789
# ======================================
# Najlepszy model zapisany.
# Epoch [13/30] | Batch [100/1500] | Batch Loss: 1.7071
# Epoch [13/30] | Batch [200/1500] | Batch Loss: 1.5992
# Epoch [13/30] | Batch [300/1500] | Batch Loss: 1.8834
# Epoch [13/30] | Batch [400/1500] | Batch Loss: 1.8115
# Epoch [13/30] | Batch [500/1500] | Batch Loss: 1.6992
# Epoch [13/30] | Batch [600/1500] | Batch Loss: 1.7107
# Epoch [13/30] | Batch [700/1500] | Batch Loss: 1.6970
# Epoch [13/30] | Batch [800/1500] | Batch Loss: 1.9004
# Epoch [13/30] | Batch [900/1500] | Batch Loss: 1.6240
# Epoch [13/30] | Batch [1000/1500] | Batch Loss: 1.6930
# Epoch [13/30] | Batch [1100/1500] | Batch Loss: 1.6943
# Epoch [13/30] | Batch [1200/1500] | Batch Loss: 1.7637
# Epoch [13/30] | Batch [1300/1500] | Batch Loss: 1.6240
# Epoch [13/30] | Batch [1400/1500] | Batch Loss: 1.6352
# Epoch [13/30] | Batch [1500/1500] | Batch Loss: 1.8092
# ======================================
# Epoch [13/30] zakończona
# Train Loss     : 1.7647
# Train Accuracy : 68.67%
# Val Loss       : 1.9569
# Val Accuracy   : 62.06%
# Learning Rate  : 0.048316467632710365
# ======================================
# Brak poprawy. Counter: 1/5
# Epoch [14/30] | Batch [100/1500] | Batch Loss: 1.7255
# Epoch [14/30] | Batch [200/1500] | Batch Loss: 1.5832
# Epoch [14/30] | Batch [300/1500] | Batch Loss: 1.7432
# Epoch [14/30] | Batch [400/1500] | Batch Loss: 1.8429
# Epoch [14/30] | Batch [500/1500] | Batch Loss: 1.5549
# Epoch [14/30] | Batch [600/1500] | Batch Loss: 1.5040
# Epoch [14/30] | Batch [700/1500] | Batch Loss: 1.6432
# Epoch [14/30] | Batch [800/1500] | Batch Loss: 1.6091
# Epoch [14/30] | Batch [900/1500] | Batch Loss: 1.7563
# Epoch [14/30] | Batch [1000/1500] | Batch Loss: 1.8177
# Epoch [14/30] | Batch [1100/1500] | Batch Loss: 1.8675
# Epoch [14/30] | Batch [1200/1500] | Batch Loss: 1.7706
# Epoch [14/30] | Batch [1300/1500] | Batch Loss: 1.6073
# Epoch [14/30] | Batch [1400/1500] | Batch Loss: 1.6350
# Epoch [14/30] | Batch [1500/1500] | Batch Loss: 1.6852
# ======================================
# Epoch [14/30] zakończona
# Train Loss     : 1.7255
# Train Accuracy : 69.92%
# Val Loss       : 1.7988
# Val Accuracy   : 66.97%
# Learning Rate  : 0.04418113853070614
# ======================================
# Najlepszy model zapisany.
# Epoch [15/30] | Batch [100/1500] | Batch Loss: 1.3965
# Epoch [15/30] | Batch [200/1500] | Batch Loss: 1.7343
# Epoch [15/30] | Batch [300/1500] | Batch Loss: 1.6741
# Epoch [15/30] | Batch [400/1500] | Batch Loss: 1.6336
# Epoch [15/30] | Batch [500/1500] | Batch Loss: 1.7979
# Epoch [15/30] | Batch [600/1500] | Batch Loss: 1.6636
# Epoch [15/30] | Batch [700/1500] | Batch Loss: 1.6157
# Epoch [15/30] | Batch [800/1500] | Batch Loss: 1.8194
# Epoch [15/30] | Batch [900/1500] | Batch Loss: 1.5073
# Epoch [15/30] | Batch [1000/1500] | Batch Loss: 1.6995
# Epoch [15/30] | Batch [1100/1500] | Batch Loss: 1.6754
# Epoch [15/30] | Batch [1200/1500] | Batch Loss: 1.7545
# Epoch [15/30] | Batch [1300/1500] | Batch Loss: 1.7477
# Epoch [15/30] | Batch [1400/1500] | Batch Loss: 1.6746
# Epoch [15/30] | Batch [1500/1500] | Batch Loss: 1.9095
# ======================================
# Epoch [15/30] zakończona
# Train Loss     : 1.6986
# Train Accuracy : 70.78%
# Val Loss       : 1.8248
# Val Accuracy   : 66.32%
# Learning Rate  : 0.04000000000000001
# ======================================
# Brak poprawy. Counter: 1/5
# Epoch [16/30] | Batch [100/1500] | Batch Loss: 1.4392
# Epoch [16/30] | Batch [200/1500] | Batch Loss: 1.4205
# Epoch [16/30] | Batch [300/1500] | Batch Loss: 1.7849
# Epoch [16/30] | Batch [400/1500] | Batch Loss: 1.5902
# Epoch [16/30] | Batch [500/1500] | Batch Loss: 1.6454
# Epoch [16/30] | Batch [600/1500] | Batch Loss: 1.6280
# Epoch [16/30] | Batch [700/1500] | Batch Loss: 1.7667
# Epoch [16/30] | Batch [800/1500] | Batch Loss: 1.5435
# Epoch [16/30] | Batch [900/1500] | Batch Loss: 1.7381
# Epoch [16/30] | Batch [1000/1500] | Batch Loss: 1.4023
# Epoch [16/30] | Batch [1100/1500] | Batch Loss: 1.4496
# Epoch [16/30] | Batch [1200/1500] | Batch Loss: 1.5545
# Epoch [16/30] | Batch [1300/1500] | Batch Loss: 1.5911
# Epoch [16/30] | Batch [1400/1500] | Batch Loss: 1.5268
# Epoch [16/30] | Batch [1500/1500] | Batch Loss: 1.6853
# ======================================
# Epoch [16/30] zakończona
# Train Loss     : 1.6471
# Train Accuracy : 72.38%
# Val Loss       : 1.7632
# Val Accuracy   : 68.04%
# Learning Rate  : 0.03581886146929387
# ======================================
# Najlepszy model zapisany.
# Epoch [17/30] | Batch [100/1500] | Batch Loss: 1.5913
# Epoch [17/30] | Batch [200/1500] | Batch Loss: 2.0637
# Epoch [17/30] | Batch [300/1500] | Batch Loss: 1.4591
# Epoch [17/30] | Batch [400/1500] | Batch Loss: 1.6830
# Epoch [17/30] | Batch [500/1500] | Batch Loss: 1.4975
# Epoch [17/30] | Batch [600/1500] | Batch Loss: 1.8330
# Epoch [17/30] | Batch [700/1500] | Batch Loss: 1.4028
# Epoch [17/30] | Batch [800/1500] | Batch Loss: 1.4594
# Epoch [17/30] | Batch [900/1500] | Batch Loss: 1.4482
# Epoch [17/30] | Batch [1000/1500] | Batch Loss: 1.5314
# Epoch [17/30] | Batch [1100/1500] | Batch Loss: 1.4694
# Epoch [17/30] | Batch [1200/1500] | Batch Loss: 1.6453
# Epoch [17/30] | Batch [1300/1500] | Batch Loss: 1.5646
# Epoch [17/30] | Batch [1400/1500] | Batch Loss: 1.5215
# Epoch [17/30] | Batch [1500/1500] | Batch Loss: 1.7925
# ======================================
# Epoch [17/30] zakończona
# Train Loss     : 1.5818
# Train Accuracy : 74.50%
# Val Loss       : 1.8024
# Val Accuracy   : 66.88%
# Learning Rate  : 0.03168353236728962
# ======================================
# Brak poprawy. Counter: 1/5
# Epoch [18/30] | Batch [100/1500] | Batch Loss: 1.4444
# Epoch [18/30] | Batch [200/1500] | Batch Loss: 1.4095
# Epoch [18/30] | Batch [300/1500] | Batch Loss: 1.5183
# Epoch [18/30] | Batch [400/1500] | Batch Loss: 1.4049
# Epoch [18/30] | Batch [500/1500] | Batch Loss: 1.3273
# Epoch [18/30] | Batch [600/1500] | Batch Loss: 1.4924
# Epoch [18/30] | Batch [700/1500] | Batch Loss: 1.6998
# Epoch [18/30] | Batch [800/1500] | Batch Loss: 1.4740
# Epoch [18/30] | Batch [900/1500] | Batch Loss: 1.5397
# Epoch [18/30] | Batch [1000/1500] | Batch Loss: 1.5195
# Epoch [18/30] | Batch [1100/1500] | Batch Loss: 1.4293
# Epoch [18/30] | Batch [1200/1500] | Batch Loss: 1.6524
# Epoch [18/30] | Batch [1300/1500] | Batch Loss: 1.3708
# Epoch [18/30] | Batch [1400/1500] | Batch Loss: 1.5770
# Epoch [18/30] | Batch [1500/1500] | Batch Loss: 1.5214
# ======================================
# Epoch [18/30] zakończona
# Train Loss     : 1.5288
# Train Accuracy : 76.39%
# Val Loss       : 1.6410
# Val Accuracy   : 71.76%
# Learning Rate  : 0.027639320225002106
# ======================================
# Najlepszy model zapisany.
# Epoch [19/30] | Batch [100/1500] | Batch Loss: 1.2253
# Epoch [19/30] | Batch [200/1500] | Batch Loss: 1.3148
# Epoch [19/30] | Batch [300/1500] | Batch Loss: 1.3737
# Epoch [19/30] | Batch [400/1500] | Batch Loss: 1.4775
# Epoch [19/30] | Batch [500/1500] | Batch Loss: 1.5390
# Epoch [19/30] | Batch [600/1500] | Batch Loss: 1.5994
# Epoch [19/30] | Batch [700/1500] | Batch Loss: 1.2955
# Epoch [19/30] | Batch [800/1500] | Batch Loss: 1.6146
# Epoch [19/30] | Batch [900/1500] | Batch Loss: 1.4243
# Epoch [19/30] | Batch [1000/1500] | Batch Loss: 1.4684
# Epoch [19/30] | Batch [1100/1500] | Batch Loss: 1.4252
# Epoch [19/30] | Batch [1200/1500] | Batch Loss: 1.6598
# Epoch [19/30] | Batch [1300/1500] | Batch Loss: 1.3744
# Epoch [19/30] | Batch [1400/1500] | Batch Loss: 1.5006
# Epoch [19/30] | Batch [1500/1500] | Batch Loss: 1.3387
# ======================================
# Epoch [19/30] zakończona
# Train Loss     : 1.4731
# Train Accuracy : 78.19%
# Val Loss       : 1.5980
# Val Accuracy   : 72.89%
# Learning Rate  : 0.023730534276967998
# ======================================
# Najlepszy model zapisany.
# Epoch [20/30] | Batch [100/1500] | Batch Loss: 1.3342
# Epoch [20/30] | Batch [200/1500] | Batch Loss: 1.2305
# Epoch [20/30] | Batch [300/1500] | Batch Loss: 1.3684
# Epoch [20/30] | Batch [400/1500] | Batch Loss: 1.3014
# Epoch [20/30] | Batch [500/1500] | Batch Loss: 1.2086
# Epoch [20/30] | Batch [600/1500] | Batch Loss: 1.3866
# Epoch [20/30] | Batch [700/1500] | Batch Loss: 1.2945
# Epoch [20/30] | Batch [800/1500] | Batch Loss: 1.3407
# Epoch [20/30] | Batch [900/1500] | Batch Loss: 1.3333
# Epoch [20/30] | Batch [1000/1500] | Batch Loss: 1.4875
# Epoch [20/30] | Batch [1100/1500] | Batch Loss: 1.4186
# Epoch [20/30] | Batch [1200/1500] | Batch Loss: 1.3253
# Epoch [20/30] | Batch [1300/1500] | Batch Loss: 1.4090
# Epoch [20/30] | Batch [1400/1500] | Batch Loss: 1.3594
# Epoch [20/30] | Batch [1500/1500] | Batch Loss: 1.5144
# ======================================
# Epoch [20/30] zakończona
# Train Loss     : 1.4051
# Train Accuracy : 80.25%
# Val Loss       : 1.5443
# Val Accuracy   : 74.71%
# Learning Rate  : 0.020000000000000007
# ======================================
# Najlepszy model zapisany.
# Epoch [21/30] | Batch [100/1500] | Batch Loss: 1.2255
# Epoch [21/30] | Batch [200/1500] | Batch Loss: 1.4431
# Epoch [21/30] | Batch [300/1500] | Batch Loss: 1.4552
# Epoch [21/30] | Batch [400/1500] | Batch Loss: 1.3260
# Epoch [21/30] | Batch [500/1500] | Batch Loss: 1.3454
# Epoch [21/30] | Batch [600/1500] | Batch Loss: 1.4018
# Epoch [21/30] | Batch [700/1500] | Batch Loss: 1.4975
# Epoch [21/30] | Batch [800/1500] | Batch Loss: 1.4578
# Epoch [21/30] | Batch [900/1500] | Batch Loss: 1.2784
# Epoch [21/30] | Batch [1000/1500] | Batch Loss: 1.3918
# Epoch [21/30] | Batch [1100/1500] | Batch Loss: 1.5073
# Epoch [21/30] | Batch [1200/1500] | Batch Loss: 1.3979
# Epoch [21/30] | Batch [1300/1500] | Batch Loss: 1.3831
# Epoch [21/30] | Batch [1400/1500] | Batch Loss: 1.3148
# Epoch [21/30] | Batch [1500/1500] | Batch Loss: 1.3694
# ======================================
# Epoch [21/30] zakończona
# Train Loss     : 1.3444
# Train Accuracy : 82.31%
# Val Loss       : 1.4844
# Val Accuracy   : 76.71%
# Learning Rate  : 0.016488589908301078
# ======================================
# Najlepszy model zapisany.
# Epoch [22/30] | Batch [100/1500] | Batch Loss: 1.1829
# Epoch [22/30] | Batch [200/1500] | Batch Loss: 1.1780
# Epoch [22/30] | Batch [300/1500] | Batch Loss: 1.3612
# Epoch [22/30] | Batch [400/1500] | Batch Loss: 1.3743
# Epoch [22/30] | Batch [500/1500] | Batch Loss: 1.3891
# Epoch [22/30] | Batch [600/1500] | Batch Loss: 1.4565
# Epoch [22/30] | Batch [700/1500] | Batch Loss: 1.2688
# Epoch [22/30] | Batch [800/1500] | Batch Loss: 1.1882
# Epoch [22/30] | Batch [900/1500] | Batch Loss: 1.2185
# Epoch [22/30] | Batch [1000/1500] | Batch Loss: 1.3484
# Epoch [22/30] | Batch [1100/1500] | Batch Loss: 1.2603
# Epoch [22/30] | Batch [1200/1500] | Batch Loss: 1.2537
# Epoch [22/30] | Batch [1300/1500] | Batch Loss: 1.4046
# Epoch [22/30] | Batch [1400/1500] | Batch Loss: 1.3234
# Epoch [22/30] | Batch [1500/1500] | Batch Loss: 1.2147
# ======================================
# Epoch [22/30] zakończona
# Train Loss     : 1.2758
# Train Accuracy : 84.54%
# Val Loss       : 1.4290
# Val Accuracy   : 78.32%
# Learning Rate  : 0.013234775745645683
# ======================================
# Najlepszy model zapisany.
# Epoch [23/30] | Batch [100/1500] | Batch Loss: 1.1854
# Epoch [23/30] | Batch [200/1500] | Batch Loss: 1.1830
# Epoch [23/30] | Batch [300/1500] | Batch Loss: 1.1597
# Epoch [23/30] | Batch [400/1500] | Batch Loss: 1.2597
# Epoch [23/30] | Batch [500/1500] | Batch Loss: 1.1032
# Epoch [23/30] | Batch [600/1500] | Batch Loss: 1.2574
# Epoch [23/30] | Batch [700/1500] | Batch Loss: 1.2014
# Epoch [23/30] | Batch [800/1500] | Batch Loss: 1.1815
# Epoch [23/30] | Batch [900/1500] | Batch Loss: 1.2684
# Epoch [23/30] | Batch [1000/1500] | Batch Loss: 1.1702
# Epoch [23/30] | Batch [1100/1500] | Batch Loss: 1.2319
# Epoch [23/30] | Batch [1200/1500] | Batch Loss: 1.2484
# Epoch [23/30] | Batch [1300/1500] | Batch Loss: 1.1438
# Epoch [23/30] | Batch [1400/1500] | Batch Loss: 1.1851
# Epoch [23/30] | Batch [1500/1500] | Batch Loss: 1.2096
# ======================================
# Epoch [23/30] zakończona
# Train Loss     : 1.2039
# Train Accuracy : 87.10%
# Val Loss       : 1.3046
# Val Accuracy   : 82.72%
# Learning Rate  : 0.010274206980904239
# ======================================
# Najlepszy model zapisany.
# Epoch [24/30] | Batch [100/1500] | Batch Loss: 1.1724
# Epoch [24/30] | Batch [200/1500] | Batch Loss: 1.1042
# Epoch [24/30] | Batch [300/1500] | Batch Loss: 1.1016
# Epoch [24/30] | Batch [400/1500] | Batch Loss: 1.0381
# Epoch [24/30] | Batch [500/1500] | Batch Loss: 1.0727
# Epoch [24/30] | Batch [600/1500] | Batch Loss: 1.0562
# Epoch [24/30] | Batch [700/1500] | Batch Loss: 1.1877
# Epoch [24/30] | Batch [800/1500] | Batch Loss: 1.2312
# Epoch [24/30] | Batch [900/1500] | Batch Loss: 1.1972
# Epoch [24/30] | Batch [1000/1500] | Batch Loss: 1.2005
# Epoch [24/30] | Batch [1100/1500] | Batch Loss: 1.0881
# Epoch [24/30] | Batch [1200/1500] | Batch Loss: 1.0624
# Epoch [24/30] | Batch [1300/1500] | Batch Loss: 1.1506
# Epoch [24/30] | Batch [1400/1500] | Batch Loss: 1.0866
# Epoch [24/30] | Batch [1500/1500] | Batch Loss: 1.1469
# ======================================
# Epoch [24/30] zakończona
# Train Loss     : 1.1291
# Train Accuracy : 89.60%
# Val Loss       : 1.2359
# Val Accuracy   : 85.00%
# Learning Rate  : 0.007639320225002107
# ======================================
# Najlepszy model zapisany.
# Epoch [25/30] | Batch [100/1500] | Batch Loss: 1.1034
# Epoch [25/30] | Batch [200/1500] | Batch Loss: 1.1068
# Epoch [25/30] | Batch [300/1500] | Batch Loss: 1.1049
# Epoch [25/30] | Batch [400/1500] | Batch Loss: 1.0688
# Epoch [25/30] | Batch [500/1500] | Batch Loss: 1.0198
# Epoch [25/30] | Batch [600/1500] | Batch Loss: 0.9586
# Epoch [25/30] | Batch [700/1500] | Batch Loss: 1.0891

# %%
# EWALUACJA


model.eval()

correct = 0
total = 0

with torch.no_grad():

    for images, labels in test_loader:

        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)

        _, predicted = torch.max(outputs.data, 1)

        total += labels.size(0)

        correct += (predicted == labels).sum().item()

accuracy = 100 * correct / total

print("======================================")
print(f"Accuracy: {accuracy:.2f}%")
print("======================================")
# Out:
# ======================================
# Accuracy: 77.74%
# ======================================

# %%
# ============================================================
# ZAPIS WYNIKÓW DO EXCELA
# ============================================================

from datetime import datetime
OPTIMIZER_NAME = "SGD"
SCHEDULER_NAME = "CosineAnnealingLR"
new_result = {
    
    
    "Timestamp": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
    "Dataset": DATASET_NAME,
    "Model": "Densenet121",
    "Batch Size": BATCH_SIZE,
    "Max Epochs": EPOCHS,
    "Executed Epochs": epoch + 1,
    "Learning Rate": LEARNING_RATE,
    "Patience": PATIENCE,
    "Optimizer": OPTIMIZER_NAME,
    "Scheduler": SCHEDULER_NAME,

    "Train Accuracy": round(train_accuracy, 2),
    "Validation Accuracy": round(val_accuracy, 2),
    "Test Accuracy": round(accuracy, 2),
    "Best Validation Loss": round(best_val_loss, 4),
    "Model Path": MODEL_SAVE_PATH,
    "Device": str(device)
}

# ============================================================
# ODCZYT ISTNIEJĄCEGO PLIKU
# ============================================================

if os.path.exists(RESULTS_TO_EXCEL):

    try:

        df_existing = pd.read_excel(RESULTS_TO_EXCEL)

        df_new = pd.concat(
            [df_existing, pd.DataFrame([new_result])],
            ignore_index=True
        )

    except Exception as e:

        print("Błąd odczytu Excela:", e)

        print("Tworzenie nowego pliku Excel...")

        df_new = pd.DataFrame([new_result])

else:

    df_new = pd.DataFrame([new_result])

# ============================================================
# ZAPIS EXCEL
# ============================================================

try:

    df_new.to_excel(RESULTS_TO_EXCEL, index=False)

    print("======================================")
    print(f"Wyniki zapisane do: {RESULTS_TO_EXCEL}")
    print("======================================")

except Exception as e:

    print("======================================")
    print("BŁĄD ZAPISU EXCEL")
    print(e)
    print("======================================")
# Out:
# ======================================
# Wyniki zapisane do: training_results_densenet_augumentacja.xlsx
# ======================================

# %%
# ============================================================
# ZAPIS MODELU
# ============================================================

checkpoint = {
    "epoch": epoch + 1,
    "model_state_dict": model.state_dict(),
    "optimizer_state_dict": optimizer.state_dict(),
    "scheduler_state_dict": scheduler.state_dict(),
    "best_val_loss": best_val_loss,
    "dataset": DATASET_NAME,
    "batch_size": BATCH_SIZE,
    "learning_rate": LEARNING_RATE,
}

torch.save(checkpoint, MODEL_SAVE_PATH_CHECKPOINT)

print("======================================")
print(f"Model zapisany do: {MODEL_SAVE_PATH_CHECKPOINT}")
print("======================================")
# Out:
# ======================================
# Model zapisany do: models/t_checkpoint_augumentacja_densenet_cifar100_64batch_20epochs_0.05lr.pth
# ======================================
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
