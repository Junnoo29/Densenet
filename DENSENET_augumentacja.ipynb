# %%
import os
import pandas as pd


import torch
import torch.nn as nn
import torch.optim as optim


import torchvision
import torchvision.transforms as transforms
from torch.utils.data import ConcatDataset

from torchvision.models import densenet121
from torch.utils.data import DataLoader, random_split


print(torch.__version__)
print(torch.version.cuda)
print(torch.backends.cudnn.enabled)
# Out:
# 2.2.0+cu121
# 12.1
# True

# %%
#KONIGURaCJa
# dataset:
# "CIFAR10"
# "CIFAR100"
DATASET_NAME = "CIFAR10"


BATCH_SIZE = 64
EPOCHS = 20
LEARNING_RATE = 0.01


MODEL_SAVE_PATH_CHECKPOINT = f"models/t_checkpoint_augumentacja_densenet_{DATASET_NAME.lower()}_{BATCH_SIZE}batch_{EPOCHS}epochs_{LEARNING_RATE}lr.pth"
MODEL_SAVE_PATH = f"models/densenet_model_augumentacja_{DATASET_NAME.lower()}_{BATCH_SIZE}batch_{EPOCHS}epochs_{LEARNING_RATE}lr.pth"
RESULTS_TO_EXCEL = "training_results_densenet_augumentacja.xlsx"
# EARLY STOPPING
PATIENCE = 5

# %%
#device
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print("======================================")
print("DEVICE:", device)
print("======================================")
# Out:
# ======================================
# DEVICE: cuda
# ======================================

# %%
# TRANSFORMACJE

# Oryginalne dane
transform_base = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(
        (0.4914, 0.4822, 0.4465),
        (0.2023, 0.1994, 0.2010)
    )
])

# Augmentacja nr 1
transform_aug1 = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32, padding=4),
    transforms.RandomRotation(15),
    transforms.ToTensor(),
    transforms.Normalize(
        (0.4914, 0.4822, 0.4465),
        (0.2023, 0.1994, 0.2010)
    )
])
# Augmentacja nr 2
transform_aug2 = transforms.Compose([
    transforms.ColorJitter(
        brightness=0.2,
        contrast=0.2,
        saturation=0.2
    ),
    transforms.RandomAffine(
        degrees=20,
        translate=(0.1, 0.1)
    ),
    transforms.ToTensor(),
    transforms.Normalize(
        (0.4914, 0.4822, 0.4465),
        (0.2023, 0.1994, 0.2010)
    )
])

# Test bez augmentacji
transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(
        (0.4914, 0.4822, 0.4465),
        (0.2023, 0.1994, 0.2010)
    )
])

# %%
# ============================================================
# DATASET
# ============================================================

if DATASET_NAME == "CIFAR10":

    NUM_CLASSES = 10

    # ORYGINALNY DATASET
    dataset_original = torchvision.datasets.CIFAR10(
        root="./data",
        train=True,
        download=True,
        transform=transform_base
    )

    # AUGMENTOWANA KOPIA 1
    dataset_aug1 = torchvision.datasets.CIFAR10(
        root="./data",
        train=True,
        download=True,
        transform=transform_aug1
    )

    # AUGMENTOWANA KOPIA 2
    dataset_aug2 = torchvision.datasets.CIFAR10(
        root="./data",
        train=True,
        download=True,
        transform=transform_aug2
    )

    # POŁĄCZENIE DATASETÓW
    full_train_dataset = ConcatDataset([
        dataset_original,
        dataset_aug1,
        dataset_aug2
    ])
    test_dataset = torchvision.datasets.CIFAR10(
        root="./data",
        train=False,
        download=True,
        transform=transform_test
    )

elif DATASET_NAME == "CIFAR100":

    NUM_CLASSES = 100

    dataset_original = torchvision.datasets.CIFAR100(
        root="./data",
        train=True,
        download=True,
        transform=transform_base
    )
    dataset_aug1 = torchvision.datasets.CIFAR100(
        root="./data",
        train=True,
        download=True,
        transform=transform_aug1
    )

    dataset_aug2 = torchvision.datasets.CIFAR100(
        root="./data",
        train=True,
        download=True,
        transform=transform_aug2
    )

    full_train_dataset = ConcatDataset([
        dataset_original,
        dataset_aug1,
        dataset_aug2
    ])

    test_dataset = torchvision.datasets.CIFAR100(
        root="./data",
        train=False,
        download=True,
        transform=transform_test
    )

else:
    raise ValueError("DATASET_NAME musi być CIFAR10 albo CIFAR100")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# ============================================================
# PODZIAŁ TRAIN / VALIDATION
# ============================================================

train_size = int(0.8 * len(full_train_dataset))
val_size = len(full_train_dataset) - train_size

train_dataset, val_dataset = random_split(
    full_train_dataset,
    [train_size, val_size]
)

# %%
# DATALOADER
train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=0,
    pin_memory=torch.cuda.is_available()
)

val_loader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=0,
    pin_memory=torch.cuda.is_available()
)

test_loader = DataLoader(
    test_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=0,
    pin_memory=torch.cuda.is_available()
)

# %%
# MODEL DENSENET121


# weights=None -> brak pretrained weights
model = densenet121(weights=None)

# zmiana pierwszej warstwy dla CIFAR
model.features.conv0 = nn.Conv2d(
    3, #licza kanałów wejściowych (RGB)
    64, # liczba kanałów wyjściowych (zgodna z oryginalnym modelem)
    kernel_size=3,# rozmiar filtra
    stride=1, #krok przesuwania filtra
    padding=1,#dodanie paddingu, żeby zachować rozmiar obrazu bo filtr 3x3 nie miesci sie
    bias=False
)

# usunięcie maxpool
model.features.pool0 = nn.Identity()

# zmiana klasyfikatora
model.classifier = nn.Sequential(
    nn.Dropout(0.3),
    nn.Linear(  
    model.classifier.in_features,
    NUM_CLASSES)
)

model = model.to(device)

print("======================================")
print(model)
print("======================================")
# Out:
# ======================================
# DenseNet(
#   (features): Sequential(
#     (conv0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu0): ReLU(inplace=True)
#     (pool0): Identity()
#     (denseblock1): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition1): _Transition(
#       (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock2): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition2): _Transition(
#       (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock3): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer17): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer18): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer19): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer20): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer21): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer22): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer23): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer24): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition3): _Transition(
#       (norm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock4): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (norm5): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.3, inplace=False)
#     (1): Linear(in_features=1024, out_features=100, bias=True)
#   )
# )
# ======================================

# %%
# LOSS + OPTIMIZER


criterion = nn.CrossEntropyLoss(
    label_smoothing=0.1
)
# optimizer = optim.SGD(
#     model.parameters(),
#     lr=LEARNING_RATE,
#     momentum=0.9,
#     weight_decay=5e-4
# )
# optimizer = optim.Adam(
#     model.parameters(),
#     lr=LEARNING_RATE
# )
# optimizer = optim.SGD(
#     model.parameters(),
#     lr=LEARNING_RATE,
#     momentum=0.9,
#     weight_decay=5e-4
# )
optimizer = optim.AdamW(
    model.parameters(),
    lr=1e-4,
    weight_decay=0.05
)
# scheduler = optim.lr_scheduler.StepLR(
#     optimizer,
#     step_size=5,
#     gamma=0.1
# )


scheduler = optim.lr_scheduler.CosineAnnealingLR(
    optimizer,
    T_max=EPOCHS
)

# %%
# ============================================================
# EARLY STOPPING VARIABLES
# ============================================================

best_val_loss = float("inf")
early_stop_counter = 0

# %%
#pętla treningowa


print("======================================")
print("START TRENINGU")
print("======================================")

for epoch in range(EPOCHS):

    model.train()

    running_loss = 0.0
    correct_train = 0
    total_train = 0

    for batch_idx, (images, labels) in enumerate(train_loader):

        images = images.to(device)
        labels = labels.to(device)

        # zerowanie gradientów
        optimizer.zero_grad()

        # forward
        outputs = model(images)

        # loss
        loss = criterion(outputs, labels)

        # backward
        loss.backward() #liczenie gradientow

        # update wag
        optimizer.step()

        running_loss += loss.item()
        
        # accuracy train
        _, predicted = torch.max(outputs , 1)

        total_train += labels.size(0)

        correct_train += (predicted == labels).sum().item()
        
        # ====================================================
        # BATCH LOGGING
        # ====================================================

        if (batch_idx + 1) % 100 == 0:

            print(
                f"Epoch [{epoch+1}/{EPOCHS}] | "
                f"Batch [{batch_idx+1}/{len(train_loader)}] | "
                f"Batch Loss: {loss.item():.4f}"
            )

        
    # ========================================================
    # TRAIN METRICS
    # ========================================================

    train_loss = running_loss / len(train_loader)

    train_accuracy = 100 * correct_train / total_train
        
    # ========================================================
    # VALIDATION
    # ========================================================

    model.eval()

    running_val_loss = 0.0

    correct = 0
    total = 0

    with torch.no_grad():

        for images, labels in val_loader:

            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)

            loss = criterion(outputs, labels)

            running_val_loss += loss.item()

            _, predicted = torch.max(outputs, 1)

            total += labels.size(0)

            correct += (predicted == labels).sum().item()

    # ========================================================
    # VALIDATION METRICS
    # ========================================================

    val_loss = running_val_loss / len(val_loader)

    val_accuracy = 100 * correct / total

    # ========================================================
    # SCHEDULER STEP
    # ========================================================

    scheduler.step()
        

    # ========================================================
    # EPOCH LOGGING
    # ========================================================

    current_lr = optimizer.param_groups[0]["lr"]

    print("======================================")
    print(f"Epoch [{epoch+1}/{EPOCHS}] zakończona")
    print(f"Train Loss     : {train_loss:.4f}")
    print(f"Train Accuracy : {train_accuracy:.2f}%")
    print(f"Val Loss       : {val_loss:.4f}")
    print(f"Val Accuracy   : {val_accuracy:.2f}%")
    print(f"Learning Rate  : {current_lr}")
    print("======================================")

    # ========================================================
    # EARLY STOPPING
    # ========================================================

    if val_loss < best_val_loss:

        best_val_loss = val_loss
        early_stop_counter = 0

        torch.save(model.state_dict(), MODEL_SAVE_PATH)

        print("Najlepszy model zapisany.")

    else:

        early_stop_counter += 1

        print(f"Brak poprawy. Counter: {early_stop_counter}/{PATIENCE}")

    if early_stop_counter >= PATIENCE:

        print("======================================")
        print("EARLY STOPPING")
        print("======================================")
        break

print("======================================")
print("KONIEC TRENINGU")
print("======================================")

# ============================================================
# WCZYTANIE NAJLEPSZEGO MODELU
# ============================================================

model.load_state_dict(torch.load(MODEL_SAVE_PATH))
model.to(device)
# Out:
# ======================================
# START TRENINGU
# ======================================
# Epoch [1/40] | Batch [100/1250] | Batch Loss: 4.3710
# Epoch [1/40] | Batch [200/1250] | Batch Loss: 4.2357
# Epoch [1/40] | Batch [300/1250] | Batch Loss: 4.0208
# Epoch [1/40] | Batch [400/1250] | Batch Loss: 4.0031
# Epoch [1/40] | Batch [500/1250] | Batch Loss: 3.9869
# Epoch [1/40] | Batch [600/1250] | Batch Loss: 3.9091
# Epoch [1/40] | Batch [700/1250] | Batch Loss: 4.1080
# Epoch [1/40] | Batch [800/1250] | Batch Loss: 3.9824
# Epoch [1/40] | Batch [900/1250] | Batch Loss: 3.7272
# Epoch [1/40] | Batch [1000/1250] | Batch Loss: 3.8955
# Epoch [1/40] | Batch [1100/1250] | Batch Loss: 3.9464
# Epoch [1/40] | Batch [1200/1250] | Batch Loss: 4.1860
# ======================================
# Epoch [1/40] zakończona
# Train Loss     : 3.9725
# Train Accuracy : 9.53%
# Val Loss       : 3.5567
# Val Accuracy   : 15.34%
# Learning Rate  : 9.98458666866564e-05
# ======================================
# Najlepszy model zapisany.
# Epoch [2/40] | Batch [100/1250] | Batch Loss: 3.4387
# Epoch [2/40] | Batch [200/1250] | Batch Loss: 3.8364
# Epoch [2/40] | Batch [300/1250] | Batch Loss: 3.4548
# Epoch [2/40] | Batch [400/1250] | Batch Loss: 3.5670
# Epoch [2/40] | Batch [500/1250] | Batch Loss: 3.7011
# Epoch [2/40] | Batch [600/1250] | Batch Loss: 3.8759
# Epoch [2/40] | Batch [700/1250] | Batch Loss: 3.4941
# Epoch [2/40] | Batch [800/1250] | Batch Loss: 3.2917
# Epoch [2/40] | Batch [900/1250] | Batch Loss: 3.1912
# Epoch [2/40] | Batch [1000/1250] | Batch Loss: 3.2973
# Epoch [2/40] | Batch [1100/1250] | Batch Loss: 2.9655
# Epoch [2/40] | Batch [1200/1250] | Batch Loss: 2.9078
# ======================================
# Epoch [2/40] zakończona
# Train Loss     : 3.4206
# Train Accuracy : 17.78%
# Val Loss       : 3.1361
# Val Accuracy   : 22.73%
# Learning Rate  : 9.938441702975689e-05
# ======================================
# Najlepszy model zapisany.
# Epoch [3/40] | Batch [100/1250] | Batch Loss: 3.0856
# Epoch [3/40] | Batch [200/1250] | Batch Loss: 3.1243
# Epoch [3/40] | Batch [300/1250] | Batch Loss: 3.0694
# Epoch [3/40] | Batch [400/1250] | Batch Loss: 3.2730
# Epoch [3/40] | Batch [500/1250] | Batch Loss: 3.1839
# Epoch [3/40] | Batch [600/1250] | Batch Loss: 3.0448
# Epoch [3/40] | Batch [700/1250] | Batch Loss: 3.5338
# Epoch [3/40] | Batch [800/1250] | Batch Loss: 3.2276
# Epoch [3/40] | Batch [900/1250] | Batch Loss: 2.6660
# Epoch [3/40] | Batch [1000/1250] | Batch Loss: 3.4316
# Epoch [3/40] | Batch [1100/1250] | Batch Loss: 3.3855
# Epoch [3/40] | Batch [1200/1250] | Batch Loss: 2.7073
# ======================================
# Epoch [3/40] zakończona
# Train Loss     : 3.0414
# Train Accuracy : 24.64%
# Val Loss       : 2.8629
# Val Accuracy   : 27.79%
# Learning Rate  : 9.861849601988383e-05
# ======================================
# Najlepszy model zapisany.
# Epoch [4/40] | Batch [100/1250] | Batch Loss: 2.8513
# Epoch [4/40] | Batch [200/1250] | Batch Loss: 2.7644
# Epoch [4/40] | Batch [300/1250] | Batch Loss: 2.3547
# Epoch [4/40] | Batch [400/1250] | Batch Loss: 2.4156
# Epoch [4/40] | Batch [500/1250] | Batch Loss: 2.2548
# Epoch [4/40] | Batch [600/1250] | Batch Loss: 2.8825
# Epoch [4/40] | Batch [700/1250] | Batch Loss: 2.8689
# Epoch [4/40] | Batch [800/1250] | Batch Loss: 2.4720
# Epoch [4/40] | Batch [900/1250] | Batch Loss: 3.1892
# Epoch [4/40] | Batch [1000/1250] | Batch Loss: 2.9925
# Epoch [4/40] | Batch [1100/1250] | Batch Loss: 2.6232
# Epoch [4/40] | Batch [1200/1250] | Batch Loss: 2.9683
# ======================================
# Epoch [4/40] zakończona
# Train Loss     : 2.7477
# Train Accuracy : 30.30%
# Val Loss       : 2.6126
# Val Accuracy   : 33.04%
# Learning Rate  : 9.755282581475767e-05
# ======================================
# Najlepszy model zapisany.
# Epoch [5/40] | Batch [100/1250] | Batch Loss: 2.5211
# Epoch [5/40] | Batch [200/1250] | Batch Loss: 2.8375
# Epoch [5/40] | Batch [300/1250] | Batch Loss: 2.3412
# Epoch [5/40] | Batch [400/1250] | Batch Loss: 2.5067
# Epoch [5/40] | Batch [500/1250] | Batch Loss: 2.4886
# Epoch [5/40] | Batch [600/1250] | Batch Loss: 2.6572
# Epoch [5/40] | Batch [700/1250] | Batch Loss: 2.5154
# Epoch [5/40] | Batch [800/1250] | Batch Loss: 2.4849
# Epoch [5/40] | Batch [900/1250] | Batch Loss: 1.9579
# Epoch [5/40] | Batch [1000/1250] | Batch Loss: 2.1449
# Epoch [5/40] | Batch [1100/1250] | Batch Loss: 3.1142
# Epoch [5/40] | Batch [1200/1250] | Batch Loss: 1.9366
# ======================================
# Epoch [5/40] zakończona
# Train Loss     : 2.5178
# Train Accuracy : 34.98%
# Val Loss       : 2.3994
# Val Accuracy   : 37.14%
# Learning Rate  : 9.619397662556432e-05
# ======================================
# Najlepszy model zapisany.
# Epoch [6/40] | Batch [100/1250] | Batch Loss: 2.5135
# Epoch [6/40] | Batch [200/1250] | Batch Loss: 2.3386
# Epoch [6/40] | Batch [300/1250] | Batch Loss: 2.3993
# Epoch [6/40] | Batch [400/1250] | Batch Loss: 2.5632
# Epoch [6/40] | Batch [500/1250] | Batch Loss: 2.2234
# Epoch [6/40] | Batch [600/1250] | Batch Loss: 2.1328
# Epoch [6/40] | Batch [700/1250] | Batch Loss: 2.0863
# Epoch [6/40] | Batch [800/1250] | Batch Loss: 2.2338
# Epoch [6/40] | Batch [900/1250] | Batch Loss: 1.6688
# Epoch [6/40] | Batch [1000/1250] | Batch Loss: 1.7814
# Epoch [6/40] | Batch [1100/1250] | Batch Loss: 2.5648
# Epoch [6/40] | Batch [1200/1250] | Batch Loss: 2.1044
# ======================================
# Epoch [6/40] zakończona
# Train Loss     : 2.3131
# Train Accuracy : 39.23%
# Val Loss       : 2.2269
# Val Accuracy   : 41.00%
# Learning Rate  : 9.455032620941837e-05
# ======================================
# Najlepszy model zapisany.
# Epoch [7/40] | Batch [100/1250] | Batch Loss: 1.7869
# Epoch [7/40] | Batch [200/1250] | Batch Loss: 1.8618
# Epoch [7/40] | Batch [300/1250] | Batch Loss: 2.1735
# Epoch [7/40] | Batch [400/1250] | Batch Loss: 2.1555
# Epoch [7/40] | Batch [500/1250] | Batch Loss: 2.2600
# Epoch [7/40] | Batch [600/1250] | Batch Loss: 2.2021
# Epoch [7/40] | Batch [700/1250] | Batch Loss: 2.0275
# Epoch [7/40] | Batch [800/1250] | Batch Loss: 2.3017
# Epoch [7/40] | Batch [900/1250] | Batch Loss: 2.1318
# Epoch [7/40] | Batch [1000/1250] | Batch Loss: 2.0647
# Epoch [7/40] | Batch [1100/1250] | Batch Loss: 2.2563
# Epoch [7/40] | Batch [1200/1250] | Batch Loss: 2.3199
# ======================================
# Epoch [7/40] zakończona
# Train Loss     : 2.1550
# Train Accuracy : 42.69%
# Val Loss       : 2.0996
# Val Accuracy   : 43.21%
# Learning Rate  : 9.26320082177046e-05
# ======================================
# Najlepszy model zapisany.
# Epoch [8/40] | Batch [100/1250] | Batch Loss: 1.8729
# Epoch [8/40] | Batch [200/1250] | Batch Loss: 2.0859
# Epoch [8/40] | Batch [300/1250] | Batch Loss: 1.9976
# Epoch [8/40] | Batch [400/1250] | Batch Loss: 2.1560
# Epoch [8/40] | Batch [500/1250] | Batch Loss: 2.0319
# Epoch [8/40] | Batch [600/1250] | Batch Loss: 2.3973
# Epoch [8/40] | Batch [700/1250] | Batch Loss: 1.5741
# Epoch [8/40] | Batch [800/1250] | Batch Loss: 1.6505
# Epoch [8/40] | Batch [900/1250] | Batch Loss: 1.9997
# Epoch [8/40] | Batch [1000/1250] | Batch Loss: 1.9625
# Epoch [8/40] | Batch [1100/1250] | Batch Loss: 1.8171
# Epoch [8/40] | Batch [1200/1250] | Batch Loss: 1.9779
# ======================================
# Epoch [8/40] zakończona
# Train Loss     : 2.0041
# Train Accuracy : 46.16%
# Val Loss       : 1.9875
# Val Accuracy   : 45.88%
# Learning Rate  : 9.045084971874737e-05
# ======================================
# Najlepszy model zapisany.
# Epoch [9/40] | Batch [100/1250] | Batch Loss: 1.9874
# Epoch [9/40] | Batch [200/1250] | Batch Loss: 1.9995
# Epoch [9/40] | Batch [300/1250] | Batch Loss: 1.7981
# Epoch [9/40] | Batch [400/1250] | Batch Loss: 1.9658
# Epoch [9/40] | Batch [500/1250] | Batch Loss: 1.5575
# Epoch [9/40] | Batch [600/1250] | Batch Loss: 1.4314
# Epoch [9/40] | Batch [700/1250] | Batch Loss: 1.6490
# Epoch [9/40] | Batch [800/1250] | Batch Loss: 1.9180
# Epoch [9/40] | Batch [900/1250] | Batch Loss: 1.4238
# Epoch [9/40] | Batch [1000/1250] | Batch Loss: 1.5396
# Epoch [9/40] | Batch [1100/1250] | Batch Loss: 1.9737
# Epoch [9/40] | Batch [1200/1250] | Batch Loss: 1.9411
# ======================================
# Epoch [9/40] zakończona
# Train Loss     : 1.8938
# Train Accuracy : 48.85%
# Val Loss       : 1.8924
# Val Accuracy   : 48.16%
# Learning Rate  : 8.802029828000154e-05
# ======================================
# Najlepszy model zapisany.
# Epoch [10/40] | Batch [100/1250] | Batch Loss: 1.8418
# Epoch [10/40] | Batch [200/1250] | Batch Loss: 1.9522
# Epoch [10/40] | Batch [300/1250] | Batch Loss: 1.5272
# Epoch [10/40] | Batch [400/1250] | Batch Loss: 1.9034
# Epoch [10/40] | Batch [500/1250] | Batch Loss: 1.9057
# Epoch [10/40] | Batch [600/1250] | Batch Loss: 2.0727
# Epoch [10/40] | Batch [700/1250] | Batch Loss: 1.6802
# Epoch [10/40] | Batch [800/1250] | Batch Loss: 1.6770
# Epoch [10/40] | Batch [900/1250] | Batch Loss: 1.8806
# Epoch [10/40] | Batch [1000/1250] | Batch Loss: 1.9671
# Epoch [10/40] | Batch [1100/1250] | Batch Loss: 1.2794
# Epoch [10/40] | Batch [1200/1250] | Batch Loss: 1.9794
# ======================================
# Epoch [10/40] zakończona
# Train Loss     : 1.7861
# Train Accuracy : 51.25%
# Val Loss       : 1.8580
# Val Accuracy   : 49.22%
# Learning Rate  : 8.535533905932737e-05
# ======================================
# Najlepszy model zapisany.
# Epoch [11/40] | Batch [100/1250] | Batch Loss: 1.7438
# Epoch [11/40] | Batch [200/1250] | Batch Loss: 1.4059
# Epoch [11/40] | Batch [300/1250] | Batch Loss: 1.2688
# Epoch [11/40] | Batch [400/1250] | Batch Loss: 1.9528
# Epoch [11/40] | Batch [500/1250] | Batch Loss: 1.3809
# Epoch [11/40] | Batch [600/1250] | Batch Loss: 1.6798
# Epoch [11/40] | Batch [700/1250] | Batch Loss: 1.8900
# Epoch [11/40] | Batch [800/1250] | Batch Loss: 1.6039
# Epoch [11/40] | Batch [900/1250] | Batch Loss: 1.9794
# Epoch [11/40] | Batch [1000/1250] | Batch Loss: 1.6760
# Epoch [11/40] | Batch [1100/1250] | Batch Loss: 2.1525
# Epoch [11/40] | Batch [1200/1250] | Batch Loss: 1.5445
# ======================================
# Epoch [11/40] zakończona
# Train Loss     : 1.6965
# Train Accuracy : 53.45%
# Val Loss       : 1.7870
# Val Accuracy   : 50.61%
# Learning Rate  : 8.247240241650918e-05
# ======================================
# Najlepszy model zapisany.
# Epoch [12/40] | Batch [100/1250] | Batch Loss: 1.3200
# Epoch [12/40] | Batch [200/1250] | Batch Loss: 1.8773
# Epoch [12/40] | Batch [300/1250] | Batch Loss: 1.7332
# Epoch [12/40] | Batch [400/1250] | Batch Loss: 1.6083
# Epoch [12/40] | Batch [500/1250] | Batch Loss: 1.4119
# Epoch [12/40] | Batch [600/1250] | Batch Loss: 1.5382
# Epoch [12/40] | Batch [700/1250] | Batch Loss: 1.8720
# Epoch [12/40] | Batch [800/1250] | Batch Loss: 1.2520
# Epoch [12/40] | Batch [900/1250] | Batch Loss: 1.8403
# Epoch [12/40] | Batch [1000/1250] | Batch Loss: 1.6569
# Epoch [12/40] | Batch [1100/1250] | Batch Loss: 1.9902
# Epoch [12/40] | Batch [1200/1250] | Batch Loss: 1.2527
# ======================================
# Epoch [12/40] zakończona
# Train Loss     : 1.6167
# Train Accuracy : 55.02%
# Val Loss       : 1.7350
# Val Accuracy   : 52.49%
# Learning Rate  : 7.938926261462365e-05
# ======================================
# Najlepszy model zapisany.
# Epoch [13/40] | Batch [100/1250] | Batch Loss: 1.4266
# Epoch [13/40] | Batch [200/1250] | Batch Loss: 1.2897
# Epoch [13/40] | Batch [300/1250] | Batch Loss: 1.2778
# Epoch [13/40] | Batch [400/1250] | Batch Loss: 1.2106
# Epoch [13/40] | Batch [500/1250] | Batch Loss: 1.2153
# Epoch [13/40] | Batch [600/1250] | Batch Loss: 1.2990
# Epoch [13/40] | Batch [700/1250] | Batch Loss: 1.0026
# Epoch [13/40] | Batch [800/1250] | Batch Loss: 1.7691
# Epoch [13/40] | Batch [900/1250] | Batch Loss: 1.6209
# Epoch [13/40] | Batch [1000/1250] | Batch Loss: 1.4509
# Epoch [13/40] | Batch [1100/1250] | Batch Loss: 1.4299
# Epoch [13/40] | Batch [1200/1250] | Batch Loss: 1.2458
# ======================================
# Epoch [13/40] zakończona
# Train Loss     : 1.5354
# Train Accuracy : 57.02%
# Val Loss       : 1.6785
# Val Accuracy   : 54.04%
# Learning Rate  : 7.612492823579742e-05
# ======================================
# Najlepszy model zapisany.
# Epoch [14/40] | Batch [100/1250] | Batch Loss: 1.7089
# Epoch [14/40] | Batch [200/1250] | Batch Loss: 1.8054
# Epoch [14/40] | Batch [300/1250] | Batch Loss: 1.6038
# Epoch [14/40] | Batch [400/1250] | Batch Loss: 1.2375
# Epoch [14/40] | Batch [500/1250] | Batch Loss: 1.4928
# Epoch [14/40] | Batch [600/1250] | Batch Loss: 1.5434
# Epoch [14/40] | Batch [700/1250] | Batch Loss: 1.3364
# Epoch [14/40] | Batch [800/1250] | Batch Loss: 1.1633
# Epoch [14/40] | Batch [900/1250] | Batch Loss: 1.5909
# Epoch [14/40] | Batch [1000/1250] | Batch Loss: 0.9925
# Epoch [14/40] | Batch [1100/1250] | Batch Loss: 1.7367
# Epoch [14/40] | Batch [1200/1250] | Batch Loss: 1.3157
# ======================================
# Epoch [14/40] zakończona
# Train Loss     : 1.4690
# Train Accuracy : 58.84%
# Val Loss       : 1.6495
# Val Accuracy   : 54.55%
# Learning Rate  : 7.269952498697731e-05
# ======================================
# Najlepszy model zapisany.
# Epoch [15/40] | Batch [100/1250] | Batch Loss: 1.1543
# Epoch [15/40] | Batch [200/1250] | Batch Loss: 1.6941
# Epoch [15/40] | Batch [300/1250] | Batch Loss: 1.3238
# Epoch [15/40] | Batch [400/1250] | Batch Loss: 0.7343
# Epoch [15/40] | Batch [500/1250] | Batch Loss: 1.0894
# Epoch [15/40] | Batch [600/1250] | Batch Loss: 1.8228
# Epoch [15/40] | Batch [700/1250] | Batch Loss: 1.5538
# Epoch [15/40] | Batch [800/1250] | Batch Loss: 1.4731
# Epoch [15/40] | Batch [900/1250] | Batch Loss: 1.4525
# Epoch [15/40] | Batch [1000/1250] | Batch Loss: 1.8114
# Epoch [15/40] | Batch [1100/1250] | Batch Loss: 1.2233
# Epoch [15/40] | Batch [1200/1250] | Batch Loss: 1.3587
# ======================================
# Epoch [15/40] zakończona
# Train Loss     : 1.4051
# Train Accuracy : 60.34%
# Val Loss       : 1.6060
# Val Accuracy   : 55.57%
# Learning Rate  : 6.913417161825447e-05
# ======================================
# Najlepszy model zapisany.
# Epoch [16/40] | Batch [100/1250] | Batch Loss: 1.0889
# Epoch [16/40] | Batch [200/1250] | Batch Loss: 1.4700
# Epoch [16/40] | Batch [300/1250] | Batch Loss: 1.4660
# Epoch [16/40] | Batch [400/1250] | Batch Loss: 1.1871
# Epoch [16/40] | Batch [500/1250] | Batch Loss: 1.6155
# Epoch [16/40] | Batch [600/1250] | Batch Loss: 1.7554
# Epoch [16/40] | Batch [700/1250] | Batch Loss: 0.9897
# Epoch [16/40] | Batch [800/1250] | Batch Loss: 1.8571
# Epoch [16/40] | Batch [900/1250] | Batch Loss: 1.5129
# Epoch [16/40] | Batch [1000/1250] | Batch Loss: 1.3928
# Epoch [16/40] | Batch [1100/1250] | Batch Loss: 1.4281
# Epoch [16/40] | Batch [1200/1250] | Batch Loss: 1.1487
# ======================================
# Epoch [16/40] zakończona
# Train Loss     : 1.3358
# Train Accuracy : 61.99%
# Val Loss       : 1.6009
# Val Accuracy   : 56.25%
# Learning Rate  : 6.545084971874736e-05
# ======================================
# Najlepszy model zapisany.
# Epoch [17/40] | Batch [100/1250] | Batch Loss: 1.0743
# Epoch [17/40] | Batch [200/1250] | Batch Loss: 1.4010
# Epoch [17/40] | Batch [300/1250] | Batch Loss: 0.9875
# Epoch [17/40] | Batch [400/1250] | Batch Loss: 1.3642
# Epoch [17/40] | Batch [500/1250] | Batch Loss: 1.2050
# Epoch [17/40] | Batch [600/1250] | Batch Loss: 1.3258
# Epoch [17/40] | Batch [700/1250] | Batch Loss: 1.4305
# Epoch [17/40] | Batch [800/1250] | Batch Loss: 1.0571
# Epoch [17/40] | Batch [900/1250] | Batch Loss: 1.1080
# Epoch [17/40] | Batch [1000/1250] | Batch Loss: 0.8749
# Epoch [17/40] | Batch [1100/1250] | Batch Loss: 1.2412
# Epoch [17/40] | Batch [1200/1250] | Batch Loss: 1.1569
# ======================================
# Epoch [17/40] zakończona
# Train Loss     : 1.2816
# Train Accuracy : 63.45%
# Val Loss       : 1.5308
# Val Accuracy   : 57.66%
# Learning Rate  : 6.167226819279526e-05
# ======================================
# Najlepszy model zapisany.
# Epoch [18/40] | Batch [100/1250] | Batch Loss: 0.9769
# Epoch [18/40] | Batch [200/1250] | Batch Loss: 1.5840
# Epoch [18/40] | Batch [300/1250] | Batch Loss: 1.7183
# Epoch [18/40] | Batch [400/1250] | Batch Loss: 1.3642
# Epoch [18/40] | Batch [500/1250] | Batch Loss: 1.4198
# Epoch [18/40] | Batch [600/1250] | Batch Loss: 1.0966
# Epoch [18/40] | Batch [700/1250] | Batch Loss: 1.3793
# Epoch [18/40] | Batch [800/1250] | Batch Loss: 1.4127
# Epoch [18/40] | Batch [900/1250] | Batch Loss: 1.4763
# Epoch [18/40] | Batch [1000/1250] | Batch Loss: 1.0100
# Epoch [18/40] | Batch [1100/1250] | Batch Loss: 1.0127
# Epoch [18/40] | Batch [1200/1250] | Batch Loss: 1.2870
# ======================================
# Epoch [18/40] zakończona
# Train Loss     : 1.2203
# Train Accuracy : 65.03%
# Val Loss       : 1.5107
# Val Accuracy   : 57.94%
# Learning Rate  : 5.7821723252011525e-05
# ======================================
# Najlepszy model zapisany.
# Epoch [19/40] | Batch [100/1250] | Batch Loss: 1.1255
# Epoch [19/40] | Batch [200/1250] | Batch Loss: 0.9632
# Epoch [19/40] | Batch [300/1250] | Batch Loss: 1.1840
# Epoch [19/40] | Batch [400/1250] | Batch Loss: 1.3173
# Epoch [19/40] | Batch [500/1250] | Batch Loss: 1.0470
# Epoch [19/40] | Batch [600/1250] | Batch Loss: 1.2885
# Epoch [19/40] | Batch [700/1250] | Batch Loss: 1.0515
# Epoch [19/40] | Batch [800/1250] | Batch Loss: 1.1423
# Epoch [19/40] | Batch [900/1250] | Batch Loss: 1.3102
# Epoch [19/40] | Batch [1000/1250] | Batch Loss: 0.9155
# Epoch [19/40] | Batch [1100/1250] | Batch Loss: 1.3400
# Epoch [19/40] | Batch [1200/1250] | Batch Loss: 1.0416
# ======================================
# Epoch [19/40] zakończona
# Train Loss     : 1.1680
# Train Accuracy : 66.28%
# Val Loss       : 1.5042
# Val Accuracy   : 58.42%
# Learning Rate  : 5.392295478639223e-05
# ======================================
# Najlepszy model zapisany.
# Epoch [20/40] | Batch [100/1250] | Batch Loss: 0.7475
# Epoch [20/40] | Batch [200/1250] | Batch Loss: 1.1767
# Epoch [20/40] | Batch [300/1250] | Batch Loss: 0.9146
# Epoch [20/40] | Batch [400/1250] | Batch Loss: 1.0993
# Epoch [20/40] | Batch [500/1250] | Batch Loss: 0.9035
# Epoch [20/40] | Batch [600/1250] | Batch Loss: 0.7908
# Epoch [20/40] | Batch [700/1250] | Batch Loss: 0.9039
# Epoch [20/40] | Batch [800/1250] | Batch Loss: 1.2479
# Epoch [20/40] | Batch [900/1250] | Batch Loss: 1.0789
# Epoch [20/40] | Batch [1000/1250] | Batch Loss: 1.1865
# Epoch [20/40] | Batch [1100/1250] | Batch Loss: 0.7607
# Epoch [20/40] | Batch [1200/1250] | Batch Loss: 0.8998
# ======================================
# Epoch [20/40] zakończona
# Train Loss     : 1.1103
# Train Accuracy : 67.97%
# Val Loss       : 1.4889
# Val Accuracy   : 59.28%
# Learning Rate  : 4.999999999999998e-05
# ======================================
# Najlepszy model zapisany.
# Epoch [21/40] | Batch [100/1250] | Batch Loss: 1.0054
# Epoch [21/40] | Batch [200/1250] | Batch Loss: 0.9308
# Epoch [21/40] | Batch [300/1250] | Batch Loss: 0.8534
# Epoch [21/40] | Batch [400/1250] | Batch Loss: 1.3013
# Epoch [21/40] | Batch [500/1250] | Batch Loss: 0.9459
# Epoch [21/40] | Batch [600/1250] | Batch Loss: 0.9023
# Epoch [21/40] | Batch [700/1250] | Batch Loss: 0.9589
# Epoch [21/40] | Batch [800/1250] | Batch Loss: 1.1019
# Epoch [21/40] | Batch [900/1250] | Batch Loss: 0.8463
# Epoch [21/40] | Batch [1000/1250] | Batch Loss: 0.6327
# Epoch [21/40] | Batch [1100/1250] | Batch Loss: 0.7213
# Epoch [21/40] | Batch [1200/1250] | Batch Loss: 1.2022
# ======================================
# Epoch [21/40] zakończona
# Train Loss     : 1.0719
# Train Accuracy : 68.75%
# Val Loss       : 1.4967
# Val Accuracy   : 58.88%
# Learning Rate  : 4.607704521360774e-05
# ======================================
# Brak poprawy. Counter: 1/10
# Epoch [22/40] | Batch [100/1250] | Batch Loss: 1.2175
# Epoch [22/40] | Batch [200/1250] | Batch Loss: 0.9718
# Epoch [22/40] | Batch [300/1250] | Batch Loss: 1.0873
# Epoch [22/40] | Batch [400/1250] | Batch Loss: 1.2542
# Epoch [22/40] | Batch [500/1250] | Batch Loss: 0.8873
# Epoch [22/40] | Batch [600/1250] | Batch Loss: 0.9349
# Epoch [22/40] | Batch [700/1250] | Batch Loss: 0.9477
# Epoch [22/40] | Batch [800/1250] | Batch Loss: 0.7103
# Epoch [22/40] | Batch [900/1250] | Batch Loss: 1.2935
# Epoch [22/40] | Batch [1000/1250] | Batch Loss: 0.9736
# Epoch [22/40] | Batch [1100/1250] | Batch Loss: 1.1441
# Epoch [22/40] | Batch [1200/1250] | Batch Loss: 0.9472
# ======================================
# Epoch [22/40] zakończona
# Train Loss     : 1.0200
# Train Accuracy : 70.45%
# Val Loss       : 1.4601
# Val Accuracy   : 59.53%
# Learning Rate  : 4.217827674798845e-05
# ======================================
# Najlepszy model zapisany.
# Epoch [23/40] | Batch [100/1250] | Batch Loss: 1.0051
# Epoch [23/40] | Batch [200/1250] | Batch Loss: 0.9620
# Epoch [23/40] | Batch [300/1250] | Batch Loss: 1.0458
# Epoch [23/40] | Batch [400/1250] | Batch Loss: 0.9247
# Epoch [23/40] | Batch [500/1250] | Batch Loss: 0.8120
# Epoch [23/40] | Batch [600/1250] | Batch Loss: 0.9101
# Epoch [23/40] | Batch [700/1250] | Batch Loss: 1.3351
# Epoch [23/40] | Batch [800/1250] | Batch Loss: 1.0751
# Epoch [23/40] | Batch [900/1250] | Batch Loss: 0.7985
# Epoch [23/40] | Batch [1000/1250] | Batch Loss: 0.9825
# Epoch [23/40] | Batch [1100/1250] | Batch Loss: 1.2335
# Epoch [23/40] | Batch [1200/1250] | Batch Loss: 1.5330
# ======================================
# Epoch [23/40] zakończona
# Train Loss     : 0.9756
# Train Accuracy : 71.71%
# Val Loss       : 1.4554
# Val Accuracy   : 60.19%
# Learning Rate  : 3.832773180720472e-05
# ======================================
# Najlepszy model zapisany.
# Epoch [24/40] | Batch [100/1250] | Batch Loss: 0.7800
# Epoch [24/40] | Batch [200/1250] | Batch Loss: 1.1592
# Epoch [24/40] | Batch [300/1250] | Batch Loss: 0.8958
# Epoch [24/40] | Batch [400/1250] | Batch Loss: 0.8732
# Epoch [24/40] | Batch [500/1250] | Batch Loss: 0.9620
# Epoch [24/40] | Batch [600/1250] | Batch Loss: 0.9479
# Epoch [24/40] | Batch [700/1250] | Batch Loss: 1.4484
# Epoch [24/40] | Batch [800/1250] | Batch Loss: 1.2593
# Epoch [24/40] | Batch [900/1250] | Batch Loss: 0.9040
# Epoch [24/40] | Batch [1000/1250] | Batch Loss: 0.9473
# Epoch [24/40] | Batch [1100/1250] | Batch Loss: 1.1927
# Epoch [24/40] | Batch [1200/1250] | Batch Loss: 0.6847
# ======================================
# Epoch [24/40] zakończona
# Train Loss     : 0.9380
# Train Accuracy : 72.52%
# Val Loss       : 1.4290
# Val Accuracy   : 60.98%
# Learning Rate  : 3.4549150281252616e-05
# ======================================
# Najlepszy model zapisany.
# Epoch [25/40] | Batch [100/1250] | Batch Loss: 1.1082
# Epoch [25/40] | Batch [200/1250] | Batch Loss: 1.0101
# Epoch [25/40] | Batch [300/1250] | Batch Loss: 0.8759
# Epoch [25/40] | Batch [400/1250] | Batch Loss: 0.6469
# Epoch [25/40] | Batch [500/1250] | Batch Loss: 1.0109
# Epoch [25/40] | Batch [600/1250] | Batch Loss: 1.0088
# Epoch [25/40] | Batch [700/1250] | Batch Loss: 1.3788
# Epoch [25/40] | Batch [800/1250] | Batch Loss: 0.8955
# Epoch [25/40] | Batch [900/1250] | Batch Loss: 1.3910
# Epoch [25/40] | Batch [1000/1250] | Batch Loss: 0.8534
# Epoch [25/40] | Batch [1100/1250] | Batch Loss: 0.6555
# Epoch [25/40] | Batch [1200/1250] | Batch Loss: 0.9888
# ======================================
# Epoch [25/40] zakończona
# Train Loss     : 0.8957
# Train Accuracy : 73.73%
# Val Loss       : 1.4319
# Val Accuracy   : 60.67%
# Learning Rate  : 3.08658283817455e-05
# ======================================
# Brak poprawy. Counter: 1/10
# Epoch [26/40] | Batch [100/1250] | Batch Loss: 0.8162
# Epoch [26/40] | Batch [200/1250] | Batch Loss: 0.6548
# Epoch [26/40] | Batch [300/1250] | Batch Loss: 0.8198
# Epoch [26/40] | Batch [400/1250] | Batch Loss: 0.6715
# Epoch [26/40] | Batch [500/1250] | Batch Loss: 0.5837
# Epoch [26/40] | Batch [600/1250] | Batch Loss: 0.7603
# Epoch [26/40] | Batch [700/1250] | Batch Loss: 0.7581
# Epoch [26/40] | Batch [800/1250] | Batch Loss: 0.5266
# Epoch [26/40] | Batch [900/1250] | Batch Loss: 0.4814
# Epoch [26/40] | Batch [1000/1250] | Batch Loss: 1.1224
# Epoch [26/40] | Batch [1100/1250] | Batch Loss: 1.1956
# Epoch [26/40] | Batch [1200/1250] | Batch Loss: 0.8900
# ======================================
# Epoch [26/40] zakończona
# Train Loss     : 0.8599
# Train Accuracy : 75.06%
# Val Loss       : 1.4199
# Val Accuracy   : 61.23%
# Learning Rate  : 2.730047501302265e-05
# ======================================
# Najlepszy model zapisany.
# Epoch [27/40] | Batch [100/1250] | Batch Loss: 1.0822
# Epoch [27/40] | Batch [200/1250] | Batch Loss: 0.7206
# Epoch [27/40] | Batch [300/1250] | Batch Loss: 0.8680
# Epoch [27/40] | Batch [400/1250] | Batch Loss: 0.6295
# Epoch [27/40] | Batch [500/1250] | Batch Loss: 0.9386
# Epoch [27/40] | Batch [600/1250] | Batch Loss: 1.0344
# Epoch [27/40] | Batch [700/1250] | Batch Loss: 1.0730
# Epoch [27/40] | Batch [800/1250] | Batch Loss: 0.8065
# Epoch [27/40] | Batch [900/1250] | Batch Loss: 0.6763
# Epoch [27/40] | Batch [1000/1250] | Batch Loss: 0.9095
# Epoch [27/40] | Batch [1100/1250] | Batch Loss: 0.9287
# Epoch [27/40] | Batch [1200/1250] | Batch Loss: 0.9068
# ======================================
# Epoch [27/40] zakończona
# Train Loss     : 0.8288
# Train Accuracy : 75.52%
# Val Loss       : 1.4207
# Val Accuracy   : 62.04%
# Learning Rate  : 2.387507176420255e-05
# ======================================
# Brak poprawy. Counter: 1/10
# Epoch [28/40] | Batch [100/1250] | Batch Loss: 0.7518
# Epoch [28/40] | Batch [200/1250] | Batch Loss: 0.7231
# Epoch [28/40] | Batch [300/1250] | Batch Loss: 0.5693
# Epoch [28/40] | Batch [400/1250] | Batch Loss: 0.7065
# Epoch [28/40] | Batch [500/1250] | Batch Loss: 0.4725
# Epoch [28/40] | Batch [600/1250] | Batch Loss: 0.4358
# Epoch [28/40] | Batch [700/1250] | Batch Loss: 0.7849
# Epoch [28/40] | Batch [800/1250] | Batch Loss: 0.7364
# Epoch [28/40] | Batch [900/1250] | Batch Loss: 0.6076
# Epoch [28/40] | Batch [1000/1250] | Batch Loss: 0.5093
# Epoch [28/40] | Batch [1100/1250] | Batch Loss: 0.5622
# Epoch [28/40] | Batch [1200/1250] | Batch Loss: 0.8104
# ======================================
# Epoch [28/40] zakończona
# Train Loss     : 0.7938
# Train Accuracy : 76.58%
# Val Loss       : 1.4051
# Val Accuracy   : 61.98%
# Learning Rate  : 2.061073738537634e-05
# ======================================
# Najlepszy model zapisany.
# Epoch [29/40] | Batch [100/1250] | Batch Loss: 0.8225
# Epoch [29/40] | Batch [200/1250] | Batch Loss: 0.8713
# Epoch [29/40] | Batch [300/1250] | Batch Loss: 0.5834
# Epoch [29/40] | Batch [400/1250] | Batch Loss: 1.0356
# Epoch [29/40] | Batch [500/1250] | Batch Loss: 0.8428
# Epoch [29/40] | Batch [600/1250] | Batch Loss: 0.9010
# Epoch [29/40] | Batch [700/1250] | Batch Loss: 0.8020
# Epoch [29/40] | Batch [800/1250] | Batch Loss: 0.7721
# Epoch [29/40] | Batch [900/1250] | Batch Loss: 0.7423
# Epoch [29/40] | Batch [1000/1250] | Batch Loss: 1.1355
# Epoch [29/40] | Batch [1100/1250] | Batch Loss: 0.7008
# Epoch [29/40] | Batch [1200/1250] | Batch Loss: 0.6893
# ======================================
# Epoch [29/40] zakończona
# Train Loss     : 0.7668
# Train Accuracy : 77.48%
# Val Loss       : 1.4008
# Val Accuracy   : 62.18%
# Learning Rate  : 1.7527597583490816e-05
# ======================================
# Najlepszy model zapisany.
# Epoch [30/40] | Batch [100/1250] | Batch Loss: 0.6765
# Epoch [30/40] | Batch [200/1250] | Batch Loss: 0.8778
# Epoch [30/40] | Batch [300/1250] | Batch Loss: 0.7017
# Epoch [30/40] | Batch [400/1250] | Batch Loss: 0.5631
# Epoch [30/40] | Batch [500/1250] | Batch Loss: 0.5850
# Epoch [30/40] | Batch [600/1250] | Batch Loss: 0.7249
# Epoch [30/40] | Batch [700/1250] | Batch Loss: 0.5546
# Epoch [30/40] | Batch [800/1250] | Batch Loss: 1.0898
# Epoch [30/40] | Batch [900/1250] | Batch Loss: 0.8120
# Epoch [30/40] | Batch [1000/1250] | Batch Loss: 0.4325
# Epoch [30/40] | Batch [1100/1250] | Batch Loss: 0.8090
# Epoch [30/40] | Batch [1200/1250] | Batch Loss: 0.5673
# ======================================
# Epoch [30/40] zakończona
# Train Loss     : 0.7402
# Train Accuracy : 78.38%
# Val Loss       : 1.3957
# Val Accuracy   : 61.88%
# Learning Rate  : 1.464466094067262e-05
# ======================================
# Najlepszy model zapisany.
# Epoch [31/40] | Batch [100/1250] | Batch Loss: 0.4580
# Epoch [31/40] | Batch [200/1250] | Batch Loss: 0.9977
# Epoch [31/40] | Batch [300/1250] | Batch Loss: 0.6060
# Epoch [31/40] | Batch [400/1250] | Batch Loss: 0.5324
# Epoch [31/40] | Batch [500/1250] | Batch Loss: 0.6874
# Epoch [31/40] | Batch [600/1250] | Batch Loss: 0.7463
# Epoch [31/40] | Batch [700/1250] | Batch Loss: 0.8752
# Epoch [31/40] | Batch [800/1250] | Batch Loss: 0.5594
# Epoch [31/40] | Batch [900/1250] | Batch Loss: 0.8128
# Epoch [31/40] | Batch [1000/1250] | Batch Loss: 0.9419
# Epoch [31/40] | Batch [1100/1250] | Batch Loss: 0.9621
# Epoch [31/40] | Batch [1200/1250] | Batch Loss: 0.9673
# ======================================
# Epoch [31/40] zakończona
# Train Loss     : 0.7111
# Train Accuracy : 79.01%
# Val Loss       : 1.3952
# Val Accuracy   : 62.31%
# Learning Rate  : 1.1979701719998447e-05
# ======================================
# Najlepszy model zapisany.
# Epoch [32/40] | Batch [100/1250] | Batch Loss: 0.7461
# Epoch [32/40] | Batch [200/1250] | Batch Loss: 0.7941
# Epoch [32/40] | Batch [300/1250] | Batch Loss: 0.3521
# Epoch [32/40] | Batch [400/1250] | Batch Loss: 0.8278
# Epoch [32/40] | Batch [500/1250] | Batch Loss: 0.6412
# Epoch [32/40] | Batch [600/1250] | Batch Loss: 0.5176
# Epoch [32/40] | Batch [700/1250] | Batch Loss: 0.3617
# Epoch [32/40] | Batch [800/1250] | Batch Loss: 0.6131
# Epoch [32/40] | Batch [900/1250] | Batch Loss: 0.7943
# Epoch [32/40] | Batch [1000/1250] | Batch Loss: 0.6243
# Epoch [32/40] | Batch [1100/1250] | Batch Loss: 0.5763
# Epoch [32/40] | Batch [1200/1250] | Batch Loss: 0.6678
# ======================================
# Epoch [32/40] zakończona
# Train Loss     : 0.6891
# Train Accuracy : 79.78%
# Val Loss       : 1.3725
# Val Accuracy   : 62.64%
# Learning Rate  : 9.549150281252628e-06
# ======================================
# Najlepszy model zapisany.
# Epoch [33/40] | Batch [100/1250] | Batch Loss: 0.4422
# Epoch [33/40] | Batch [200/1250] | Batch Loss: 0.5922
# Epoch [33/40] | Batch [300/1250] | Batch Loss: 0.5288
# Epoch [33/40] | Batch [400/1250] | Batch Loss: 0.8209
# Epoch [33/40] | Batch [500/1250] | Batch Loss: 0.4209
# Epoch [33/40] | Batch [600/1250] | Batch Loss: 0.3492
# Epoch [33/40] | Batch [700/1250] | Batch Loss: 0.5551
# Epoch [33/40] | Batch [800/1250] | Batch Loss: 1.0044
# Epoch [33/40] | Batch [900/1250] | Batch Loss: 0.8741
# Epoch [33/40] | Batch [1000/1250] | Batch Loss: 0.8139
# Epoch [33/40] | Batch [1100/1250] | Batch Loss: 0.6849
# Epoch [33/40] | Batch [1200/1250] | Batch Loss: 0.5587
# ======================================
# Epoch [33/40] zakończona
# Train Loss     : 0.6763
# Train Accuracy : 80.19%
# Val Loss       : 1.3857
# Val Accuracy   : 62.70%
# Learning Rate  : 7.367991782295387e-06
# ======================================
# Brak poprawy. Counter: 1/10
# Epoch [34/40] | Batch [100/1250] | Batch Loss: 0.5636
# Epoch [34/40] | Batch [200/1250] | Batch Loss: 0.5238
# Epoch [34/40] | Batch [300/1250] | Batch Loss: 0.8172
# Epoch [34/40] | Batch [400/1250] | Batch Loss: 0.7611
# Epoch [34/40] | Batch [500/1250] | Batch Loss: 0.7732
# Epoch [34/40] | Batch [600/1250] | Batch Loss: 0.7310
# Epoch [34/40] | Batch [700/1250] | Batch Loss: 0.4760
# Epoch [34/40] | Batch [800/1250] | Batch Loss: 0.7861
# Epoch [34/40] | Batch [900/1250] | Batch Loss: 0.4394
# Epoch [34/40] | Batch [1000/1250] | Batch Loss: 0.8482
# Epoch [34/40] | Batch [1100/1250] | Batch Loss: 0.6418
# Epoch [34/40] | Batch [1200/1250] | Batch Loss: 0.5827
# ======================================
# Epoch [34/40] zakończona
# Train Loss     : 0.6570
# Train Accuracy : 80.62%
# Val Loss       : 1.3929
# Val Accuracy   : 62.49%
# Learning Rate  : 5.449673790581608e-06
# ======================================
# Brak poprawy. Counter: 2/10
# Epoch [35/40] | Batch [100/1250] | Batch Loss: 1.2152
# Epoch [35/40] | Batch [200/1250] | Batch Loss: 0.8310
# Epoch [35/40] | Batch [300/1250] | Batch Loss: 0.5648
# Epoch [35/40] | Batch [400/1250] | Batch Loss: 0.6914
# Epoch [35/40] | Batch [500/1250] | Batch Loss: 0.5489
# Epoch [35/40] | Batch [600/1250] | Batch Loss: 0.6718
# Epoch [35/40] | Batch [700/1250] | Batch Loss: 0.4416
# Epoch [35/40] | Batch [800/1250] | Batch Loss: 0.7211
# Epoch [35/40] | Batch [900/1250] | Batch Loss: 0.6589
# Epoch [35/40] | Batch [1000/1250] | Batch Loss: 0.8582
# Epoch [35/40] | Batch [1100/1250] | Batch Loss: 0.3665
# Epoch [35/40] | Batch [1200/1250] | Batch Loss: 0.4658
# ======================================
# Epoch [35/40] zakończona
# Train Loss     : 0.6393
# Train Accuracy : 81.12%
# Val Loss       : 1.3869
# Val Accuracy   : 62.71%
# Learning Rate  : 3.806023374435661e-06
# ======================================
# Brak poprawy. Counter: 3/10
# Epoch [36/40] | Batch [100/1250] | Batch Loss: 0.6645
# Epoch [36/40] | Batch [200/1250] | Batch Loss: 0.5530
# Epoch [36/40] | Batch [300/1250] | Batch Loss: 0.4356
# Epoch [36/40] | Batch [400/1250] | Batch Loss: 0.3698
# Epoch [36/40] | Batch [500/1250] | Batch Loss: 0.7007
# Epoch [36/40] | Batch [600/1250] | Batch Loss: 0.6703
# Epoch [36/40] | Batch [700/1250] | Batch Loss: 0.5242
# Epoch [36/40] | Batch [800/1250] | Batch Loss: 1.0121
# Epoch [36/40] | Batch [900/1250] | Batch Loss: 0.5425
# Epoch [36/40] | Batch [1000/1250] | Batch Loss: 0.6719
# Epoch [36/40] | Batch [1100/1250] | Batch Loss: 0.7524
# Epoch [36/40] | Batch [1200/1250] | Batch Loss: 0.4644
# ======================================
# Epoch [36/40] zakończona
# Train Loss     : 0.6341
# Train Accuracy : 81.34%
# Val Loss       : 1.3883
# Val Accuracy   : 63.07%
# Learning Rate  : 2.447174185242322e-06
# ======================================
# Brak poprawy. Counter: 4/10
# Epoch [37/40] | Batch [100/1250] | Batch Loss: 0.9793
# Epoch [37/40] | Batch [200/1250] | Batch Loss: 0.7201
# Epoch [37/40] | Batch [300/1250] | Batch Loss: 0.7760
# Epoch [37/40] | Batch [400/1250] | Batch Loss: 0.6115
# Epoch [37/40] | Batch [500/1250] | Batch Loss: 0.3994
# Epoch [37/40] | Batch [600/1250] | Batch Loss: 0.8565
# Epoch [37/40] | Batch [700/1250] | Batch Loss: 0.8258
# Epoch [37/40] | Batch [800/1250] | Batch Loss: 0.8556
# Epoch [37/40] | Batch [900/1250] | Batch Loss: 0.6323
# Epoch [37/40] | Batch [1000/1250] | Batch Loss: 0.5789
# Epoch [37/40] | Batch [1100/1250] | Batch Loss: 0.3663
# Epoch [37/40] | Batch [1200/1250] | Batch Loss: 0.5607
# ======================================
# Epoch [37/40] zakończona
# Train Loss     : 0.6274
# Train Accuracy : 81.82%
# Val Loss       : 1.3961
# Val Accuracy   : 62.48%
# Learning Rate  : 1.3815039801161715e-06
# ======================================
# Brak poprawy. Counter: 5/10
# Epoch [38/40] | Batch [100/1250] | Batch Loss: 0.7412
# Epoch [38/40] | Batch [200/1250] | Batch Loss: 0.4625
# Epoch [38/40] | Batch [300/1250] | Batch Loss: 0.4734
# Epoch [38/40] | Batch [400/1250] | Batch Loss: 0.8536
# Epoch [38/40] | Batch [500/1250] | Batch Loss: 0.6042
# Epoch [38/40] | Batch [600/1250] | Batch Loss: 0.5744
# Epoch [38/40] | Batch [700/1250] | Batch Loss: 0.5915
# Epoch [38/40] | Batch [800/1250] | Batch Loss: 0.6219
# Epoch [38/40] | Batch [900/1250] | Batch Loss: 0.8147
# Epoch [38/40] | Batch [1000/1250] | Batch Loss: 0.6405
# Epoch [38/40] | Batch [1100/1250] | Batch Loss: 0.5861
# Epoch [38/40] | Batch [1200/1250] | Batch Loss: 0.7774
# ======================================
# Epoch [38/40] zakończona
# Train Loss     : 0.6200
# Train Accuracy : 81.88%
# Val Loss       : 1.3761
# Val Accuracy   : 62.80%
# Learning Rate  : 6.155829702431167e-07
# ======================================
# Brak poprawy. Counter: 6/10
# Epoch [39/40] | Batch [100/1250] | Batch Loss: 0.7552
# Epoch [39/40] | Batch [200/1250] | Batch Loss: 0.7156
# Epoch [39/40] | Batch [300/1250] | Batch Loss: 1.1456
# Epoch [39/40] | Batch [400/1250] | Batch Loss: 0.8167
# Epoch [39/40] | Batch [500/1250] | Batch Loss: 0.6325
# Epoch [39/40] | Batch [600/1250] | Batch Loss: 0.6579
# Epoch [39/40] | Batch [700/1250] | Batch Loss: 0.6086
# Epoch [39/40] | Batch [800/1250] | Batch Loss: 0.8542
# Epoch [39/40] | Batch [900/1250] | Batch Loss: 0.6532
# Epoch [39/40] | Batch [1000/1250] | Batch Loss: 0.4821
# Epoch [39/40] | Batch [1100/1250] | Batch Loss: 0.3112
# Epoch [39/40] | Batch [1200/1250] | Batch Loss: 0.5519
# ======================================
# Epoch [39/40] zakończona
# Train Loss     : 0.6192
# Train Accuracy : 81.93%
# Val Loss       : 1.3909
# Val Accuracy   : 62.81%
# Learning Rate  : 1.5413331334360174e-07
# ======================================
# Brak poprawy. Counter: 7/10
# Epoch [40/40] | Batch [100/1250] | Batch Loss: 0.6199
# Epoch [40/40] | Batch [200/1250] | Batch Loss: 0.6022
# Epoch [40/40] | Batch [300/1250] | Batch Loss: 0.5806
# Epoch [40/40] | Batch [400/1250] | Batch Loss: 0.7458
# Epoch [40/40] | Batch [500/1250] | Batch Loss: 0.6580
# Epoch [40/40] | Batch [600/1250] | Batch Loss: 0.4521
# Epoch [40/40] | Batch [700/1250] | Batch Loss: 0.7909
# Epoch [40/40] | Batch [800/1250] | Batch Loss: 0.7004
# Epoch [40/40] | Batch [900/1250] | Batch Loss: 0.8162
# Epoch [40/40] | Batch [1000/1250] | Batch Loss: 0.2985
# Epoch [40/40] | Batch [1100/1250] | Batch Loss: 0.7845
# Epoch [40/40] | Batch [1200/1250] | Batch Loss: 0.5145
# ======================================
# Epoch [40/40] zakończona
# Train Loss     : 0.6139
# Train Accuracy : 81.71%
# Val Loss       : 1.3843
# Val Accuracy   : 62.79%
# Learning Rate  : 0.0
# ======================================
# Brak poprawy. Counter: 8/10
# ======================================
# KONIEC TRENINGU
# ======================================
# DenseNet(
#   (features): Sequential(
#     (conv0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu0): ReLU(inplace=True)
#     (pool0): Identity()
#     (denseblock1): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition1): _Transition(
#       (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock2): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition2): _Transition(
#       (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock3): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
# ...
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer17): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer18): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer19): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer20): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer21): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer22): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer23): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer24): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition3): _Transition(
#       (norm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock4): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (norm5): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.3, inplace=False)
#     (1): Linear(in_features=1024, out_features=100, bias=True)
#   )
# )

# %%
# EWALUACJA


model.eval()

correct = 0
total = 0

with torch.no_grad():

    for images, labels in test_loader:

        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)

        _, predicted = torch.max(outputs.data, 1)

        total += labels.size(0)

        correct += (predicted == labels).sum().item()

accuracy = 100 * correct / total

print("======================================")
print(f"Accuracy: {accuracy:.2f}%")
print("======================================")
# Out:
# ======================================
# Accuracy: 64.91%
# ======================================

# %%
# ============================================================
# ZAPIS WYNIKÓW DO EXCELA
# ============================================================

from datetime import datetime

new_result = {
    "Timestamp": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
    "Dataset": DATASET_NAME,
    "Batch Size": BATCH_SIZE,
    "Max Epochs": EPOCHS,
    "Executed Epochs": epoch + 1,
    "Learning Rate": LEARNING_RATE,
    "Patience": PATIENCE,
    "Train Accuracy": round(train_accuracy, 2),
    "Validation Accuracy": round(val_accuracy, 2),
    "Test Accuracy": round(accuracy, 2),
    "Best Validation Loss": round(best_val_loss, 4),
    "Model Path": MODEL_SAVE_PATH,
    "Device": str(device)
}

# ============================================================
# ODCZYT ISTNIEJĄCEGO PLIKU
# ============================================================

if os.path.exists(RESULTS_TO_EXCEL):

    try:

        df_existing = pd.read_excel(RESULTS_TO_EXCEL)

        df_new = pd.concat(
            [df_existing, pd.DataFrame([new_result])],
            ignore_index=True
        )

    except Exception as e:

        print("Błąd odczytu Excela:", e)

        print("Tworzenie nowego pliku Excel...")

        df_new = pd.DataFrame([new_result])

else:

    df_new = pd.DataFrame([new_result])

# ============================================================
# ZAPIS EXCEL
# ============================================================

try:

    df_new.to_excel(RESULTS_TO_EXCEL, index=False)

    print("======================================")
    print(f"Wyniki zapisane do: {RESULTS_TO_EXCEL}")
    print("======================================")

except Exception as e:

    print("======================================")
    print("BŁĄD ZAPISU EXCEL")
    print(e)
    print("======================================")
# Out:
# ======================================
# Wyniki zapisane do: training_results.xlsx
# ======================================

# %%
# ============================================================
# ZAPIS MODELU
# ============================================================

checkpoint = {
    "epoch": epoch + 1,
    "model_state_dict": model.state_dict(),
    "optimizer_state_dict": optimizer.state_dict(),
    "scheduler_state_dict": scheduler.state_dict(),
    "best_val_loss": best_val_loss,
    "dataset": DATASET_NAME,
    "batch_size": BATCH_SIZE,
    "learning_rate": LEARNING_RATE,
}

torch.save(checkpoint, MODEL_SAVE_PATH_CHECKPOINT)

print("======================================")
print(f"Model zapisany do: {MODEL_SAVE_PATH_CHECKPOINT}")
print("======================================")
# Out:
# ======================================
# Model zapisany do: models/t_checkpoint_cifar100_32batch_40epochs_0.0001lr.pth
# ======================================
