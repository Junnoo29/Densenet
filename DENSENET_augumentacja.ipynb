# %%
import os
import pandas as pd


import torch
import torch.nn as nn
import torch.optim as optim


import torchvision
import torchvision.transforms as transforms
from torch.utils.data import ConcatDataset

from torchvision.models import densenet121
from torch.utils.data import DataLoader, random_split


print(torch.__version__)
print(torch.version.cuda)
print(torch.backends.cudnn.enabled)
# Out:
# 2.2.0+cu121
# 12.1
# True

# %%
#KONIGURaCJa
# dataset:
# "CIFAR10"
# "CIFAR100"
DATASET_NAME = "CIFAR100"


BATCH_SIZE = 64
EPOCHS = 20
LEARNING_RATE = 0.05


MODEL_SAVE_PATH_CHECKPOINT = f"models/t_checkpoint_augumentacja_densenet_{DATASET_NAME.lower()}_{BATCH_SIZE}batch_{EPOCHS}epochs_{LEARNING_RATE}lr.pth"
MODEL_SAVE_PATH = f"models/densenet_model_augumentacja_{DATASET_NAME.lower()}_{BATCH_SIZE}batch_{EPOCHS}epochs_{LEARNING_RATE}lr.pth"
RESULTS_TO_EXCEL = "training_results_densenet_augumentacja.xlsx"
# EARLY STOPPING
PATIENCE = 5

# %%
#device
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print("======================================")
print("DEVICE:", device)
print("======================================")
# Out:
# ======================================
# DEVICE: cuda
# ======================================

# %%
# TRANSFORMACJE

# Oryginalne dane
transform_base = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(
        (0.4914, 0.4822, 0.4465),
        (0.2023, 0.1994, 0.2010)
    )
])

# Augmentacja nr 1
transform_aug1 = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32, padding=4),
    transforms.RandomRotation(15),
    transforms.ToTensor(),
    transforms.Normalize(
        (0.4914, 0.4822, 0.4465),
        (0.2023, 0.1994, 0.2010)
    )
])
# Augmentacja nr 2
transform_aug2 = transforms.Compose([
    transforms.ColorJitter(
        brightness=0.2,
        contrast=0.2,
        saturation=0.2
    ),
    transforms.RandomAffine(
        degrees=20,
        translate=(0.1, 0.1)
    ),
    transforms.ToTensor(),
    transforms.Normalize(
        (0.4914, 0.4822, 0.4465),
        (0.2023, 0.1994, 0.2010)
    )
])

# Test bez augmentacji
transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(
        (0.4914, 0.4822, 0.4465),
        (0.2023, 0.1994, 0.2010)
    )
])

# %%
# ============================================================
# DATASET
# ============================================================

if DATASET_NAME == "CIFAR10":

    NUM_CLASSES = 10

    # ORYGINALNY DATASET
    dataset_original = torchvision.datasets.CIFAR10(
        root="./data",
        train=True,
        download=True,
        transform=transform_base
    )

    # AUGMENTOWANA KOPIA 1
    dataset_aug1 = torchvision.datasets.CIFAR10(
        root="./data",
        train=True,
        download=True,
        transform=transform_aug1
    )

    # AUGMENTOWANA KOPIA 2
    dataset_aug2 = torchvision.datasets.CIFAR10(
        root="./data",
        train=True,
        download=True,
        transform=transform_aug2
    )

    # POŁĄCZENIE DATASETÓW
    full_train_dataset = ConcatDataset([
        dataset_original,
        dataset_aug1,
        dataset_aug2
    ])
    test_dataset = torchvision.datasets.CIFAR10(
        root="./data",
        train=False,
        download=True,
        transform=transform_test
    )

elif DATASET_NAME == "CIFAR100":

    NUM_CLASSES = 100

    dataset_original = torchvision.datasets.CIFAR100(
        root="./data",
        train=True,
        download=True,
        transform=transform_base
    )
    dataset_aug1 = torchvision.datasets.CIFAR100(
        root="./data",
        train=True,
        download=True,
        transform=transform_aug1
    )

    dataset_aug2 = torchvision.datasets.CIFAR100(
        root="./data",
        train=True,
        download=True,
        transform=transform_aug2
    )

    full_train_dataset = ConcatDataset([
        dataset_original,
        dataset_aug1,
        dataset_aug2
    ])

    test_dataset = torchvision.datasets.CIFAR100(
        root="./data",
        train=False,
        download=True,
        transform=transform_test
    )

else:
    raise ValueError("DATASET_NAME musi być CIFAR10 albo CIFAR100")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# ============================================================
# PODZIAŁ TRAIN / VALIDATION
# ============================================================

train_size = int(0.8 * len(full_train_dataset))
val_size = len(full_train_dataset) - train_size

train_dataset, val_dataset = random_split(
    full_train_dataset,
    [train_size, val_size]
)

# %%
# DATALOADER
train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=0,
    pin_memory=torch.cuda.is_available()
)

val_loader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=0,
    pin_memory=torch.cuda.is_available()
)

test_loader = DataLoader(
    test_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=0,
    pin_memory=torch.cuda.is_available()
)

# %%
# MODEL DENSENET121


# weights=None -> brak pretrained weights
model = densenet121(weights=None)

# zmiana pierwszej warstwy dla CIFAR
model.features.conv0 = nn.Conv2d(
    3, #licza kanałów wejściowych (RGB)
    64, # liczba kanałów wyjściowych (zgodna z oryginalnym modelem)
    kernel_size=3,# rozmiar filtra
    stride=1, #krok przesuwania filtra
    padding=1,#dodanie paddingu, żeby zachować rozmiar obrazu bo filtr 3x3 nie miesci sie
    bias=False
)

# usunięcie maxpool
model.features.pool0 = nn.Identity()

# zmiana klasyfikatora
model.classifier = nn.Sequential(
    nn.Dropout(0.3),
    nn.Linear(  
    model.classifier.in_features,
    NUM_CLASSES)
)

model = model.to(device)

print("======================================")
print(model)
print("======================================")
# Out:
# ======================================
# DenseNet(
#   (features): Sequential(
#     (conv0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu0): ReLU(inplace=True)
#     (pool0): Identity()
#     (denseblock1): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition1): _Transition(
#       (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock2): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition2): _Transition(
#       (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock3): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer17): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer18): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer19): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer20): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer21): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer22): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer23): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer24): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition3): _Transition(
#       (norm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock4): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (norm5): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.3, inplace=False)
#     (1): Linear(in_features=1024, out_features=100, bias=True)
#   )
# )
# ======================================

# %%
# LOSS + OPTIMIZER


criterion = nn.CrossEntropyLoss(
    label_smoothing=0.1
)
# optimizer = optim.SGD(
#     model.parameters(),
#     lr=LEARNING_RATE,
#     momentum=0.9,
#     weight_decay=5e-4
# )
# optimizer = optim.Adam(
#     model.parameters(),
#     lr=LEARNING_RATE
# )
optimizer = optim.SGD(
    model.parameters(),
    lr=LEARNING_RATE,
    momentum=0.9,
    weight_decay=5e-4,
    nesterov=True
    
)
# optimizer = optim.AdamW(
#     model.parameters(),
#     lr=1e-4,
#     weight_decay=0.05
# )
# scheduler = optim.lr_scheduler.StepLR(
#     optimizer,
#     step_size=5,
#     gamma=0.1
# )


scheduler = optim.lr_scheduler.CosineAnnealingLR(
    optimizer,
    T_max=EPOCHS
)

# %%
# ============================================================
# EARLY STOPPING VARIABLES
# ============================================================

best_val_loss = float("inf")
early_stop_counter = 0

# %%
#pętla treningowa


print("======================================")
print("START TRENINGU")
print("======================================")

for epoch in range(EPOCHS):

    model.train()

    running_loss = 0.0
    correct_train = 0
    total_train = 0

    for batch_idx, (images, labels) in enumerate(train_loader):

        images = images.to(device)
        labels = labels.to(device)

        # zerowanie gradientów
        optimizer.zero_grad()

        # forward
        outputs = model(images)

        # loss
        loss = criterion(outputs, labels)

        # backward
        loss.backward() #liczenie gradientow

        # update wag
        optimizer.step()

        running_loss += loss.item()
        
        # accuracy train
        _, predicted = torch.max(outputs , 1)

        total_train += labels.size(0)

        correct_train += (predicted == labels).sum().item()
        
        # ====================================================
        # BATCH LOGGING
        # ====================================================

        if (batch_idx + 1) % 100 == 0:

            print(
                f"Epoch [{epoch+1}/{EPOCHS}] | "
                f"Batch [{batch_idx+1}/{len(train_loader)}] | "
                f"Batch Loss: {loss.item():.4f}"
            )

        
    # ========================================================
    # TRAIN METRICS
    # ========================================================

    train_loss = running_loss / len(train_loader)

    train_accuracy = 100 * correct_train / total_train
        
    # ========================================================
    # VALIDATION
    # ========================================================

    model.eval()

    running_val_loss = 0.0

    correct = 0
    total = 0

    with torch.no_grad():

        for images, labels in val_loader:

            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)

            loss = criterion(outputs, labels)

            running_val_loss += loss.item()

            _, predicted = torch.max(outputs, 1)

            total += labels.size(0)

            correct += (predicted == labels).sum().item()

    # ========================================================
    # VALIDATION METRICS
    # ========================================================

    val_loss = running_val_loss / len(val_loader)

    val_accuracy = 100 * correct / total

    # ========================================================
    # SCHEDULER STEP
    # ========================================================

    scheduler.step()
        

    # ========================================================
    # EPOCH LOGGING
    # ========================================================

    current_lr = optimizer.param_groups[0]["lr"]

    print("======================================")
    print(f"Epoch [{epoch+1}/{EPOCHS}] zakończona")
    print(f"Train Loss     : {train_loss:.4f}")
    print(f"Train Accuracy : {train_accuracy:.2f}%")
    print(f"Val Loss       : {val_loss:.4f}")
    print(f"Val Accuracy   : {val_accuracy:.2f}%")
    print(f"Learning Rate  : {current_lr}")
    print("======================================")

    # ========================================================
    # EARLY STOPPING
    # ========================================================

    if val_loss < best_val_loss:

        best_val_loss = val_loss
        early_stop_counter = 0

        torch.save(model.state_dict(), MODEL_SAVE_PATH)

        print("Najlepszy model zapisany.")

    else:

        early_stop_counter += 1

        print(f"Brak poprawy. Counter: {early_stop_counter}/{PATIENCE}")

    if early_stop_counter >= PATIENCE:

        print("======================================")
        print("EARLY STOPPING")
        print("======================================")
        break

print("======================================")
print("KONIEC TRENINGU")
print("======================================")

# ============================================================
# WCZYTANIE NAJLEPSZEGO MODELU
# ============================================================

model.load_state_dict(torch.load(MODEL_SAVE_PATH))
model.to(device)
# Out:
# ======================================
# START TRENINGU
# ======================================
# Epoch [1/20] | Batch [100/1875] | Batch Loss: 4.0757
# Epoch [1/20] | Batch [200/1875] | Batch Loss: 4.0360
# Epoch [1/20] | Batch [300/1875] | Batch Loss: 4.1721
# Epoch [1/20] | Batch [400/1875] | Batch Loss: 3.7676
# Epoch [1/20] | Batch [500/1875] | Batch Loss: 3.8568
# Epoch [1/20] | Batch [600/1875] | Batch Loss: 3.9524
# Epoch [1/20] | Batch [700/1875] | Batch Loss: 3.7030
# Epoch [1/20] | Batch [800/1875] | Batch Loss: 3.7330
# Epoch [1/20] | Batch [900/1875] | Batch Loss: 3.7222
# Epoch [1/20] | Batch [1000/1875] | Batch Loss: 3.3500
# Epoch [1/20] | Batch [1100/1875] | Batch Loss: 3.1212
# Epoch [1/20] | Batch [1200/1875] | Batch Loss: 3.0670
# Epoch [1/20] | Batch [1300/1875] | Batch Loss: 3.2614
# Epoch [1/20] | Batch [1400/1875] | Batch Loss: 3.1626
# Epoch [1/20] | Batch [1500/1875] | Batch Loss: 3.0449
# Epoch [1/20] | Batch [1600/1875] | Batch Loss: 3.0420
# Epoch [1/20] | Batch [1700/1875] | Batch Loss: 3.1737
# Epoch [1/20] | Batch [1800/1875] | Batch Loss: 2.9616
# ======================================
# Epoch [1/20] zakończona
# Train Loss     : 3.5317
# Train Accuracy : 20.98%
# Val Loss       : 2.9812
# Val Accuracy   : 32.98%
# Learning Rate  : 0.04969220851487845
# ======================================
# Najlepszy model zapisany.
# Epoch [2/20] | Batch [100/1875] | Batch Loss: 3.0154
# Epoch [2/20] | Batch [200/1875] | Batch Loss: 3.0676
# Epoch [2/20] | Batch [300/1875] | Batch Loss: 2.8540
# Epoch [2/20] | Batch [400/1875] | Batch Loss: 2.9270
# Epoch [2/20] | Batch [500/1875] | Batch Loss: 2.6157
# Epoch [2/20] | Batch [600/1875] | Batch Loss: 2.5323
# Epoch [2/20] | Batch [700/1875] | Batch Loss: 2.7197
# Epoch [2/20] | Batch [800/1875] | Batch Loss: 2.5003
# Epoch [2/20] | Batch [900/1875] | Batch Loss: 2.6171
# Epoch [2/20] | Batch [1000/1875] | Batch Loss: 2.5195
# Epoch [2/20] | Batch [1100/1875] | Batch Loss: 2.4216
# Epoch [2/20] | Batch [1200/1875] | Batch Loss: 2.6114
# Epoch [2/20] | Batch [1300/1875] | Batch Loss: 2.3901
# Epoch [2/20] | Batch [1400/1875] | Batch Loss: 2.6097
# Epoch [2/20] | Batch [1500/1875] | Batch Loss: 2.6027
# Epoch [2/20] | Batch [1600/1875] | Batch Loss: 2.4496
# Epoch [2/20] | Batch [1700/1875] | Batch Loss: 2.2107
# Epoch [2/20] | Batch [1800/1875] | Batch Loss: 2.5461
# ======================================
# Epoch [2/20] zakończona
# Train Loss     : 2.6176
# Train Accuracy : 43.28%
# Val Loss       : 2.4895
# Val Accuracy   : 46.71%
# Learning Rate  : 0.048776412907378844
# ======================================
# Najlepszy model zapisany.
# Epoch [3/20] | Batch [100/1875] | Batch Loss: 2.4147
# Epoch [3/20] | Batch [200/1875] | Batch Loss: 2.5213
# Epoch [3/20] | Batch [300/1875] | Batch Loss: 2.2019
# Epoch [3/20] | Batch [400/1875] | Batch Loss: 2.4209
# Epoch [3/20] | Batch [500/1875] | Batch Loss: 2.3214
# Epoch [3/20] | Batch [600/1875] | Batch Loss: 2.2087
# Epoch [3/20] | Batch [700/1875] | Batch Loss: 2.8295
# Epoch [3/20] | Batch [800/1875] | Batch Loss: 2.2323
# Epoch [3/20] | Batch [900/1875] | Batch Loss: 2.3107
# Epoch [3/20] | Batch [1000/1875] | Batch Loss: 2.2032
# Epoch [3/20] | Batch [1100/1875] | Batch Loss: 2.2695
# Epoch [3/20] | Batch [1200/1875] | Batch Loss: 2.5058
# Epoch [3/20] | Batch [1300/1875] | Batch Loss: 2.3322
# Epoch [3/20] | Batch [1400/1875] | Batch Loss: 2.3007
# Epoch [3/20] | Batch [1500/1875] | Batch Loss: 2.1053
# Epoch [3/20] | Batch [1600/1875] | Batch Loss: 2.2402
# Epoch [3/20] | Batch [1700/1875] | Batch Loss: 2.0451
# Epoch [3/20] | Batch [1800/1875] | Batch Loss: 2.2172
# ======================================
# Epoch [3/20] zakończona
# Train Loss     : 2.2901
# Train Accuracy : 52.62%
# Val Loss       : 2.2455
# Val Accuracy   : 53.81%
# Learning Rate  : 0.0472751631047092
# ======================================
# Najlepszy model zapisany.
# Epoch [4/20] | Batch [100/1875] | Batch Loss: 2.1039
# Epoch [4/20] | Batch [200/1875] | Batch Loss: 2.0855
# Epoch [4/20] | Batch [300/1875] | Batch Loss: 2.1834
# Epoch [4/20] | Batch [400/1875] | Batch Loss: 1.8696
# Epoch [4/20] | Batch [500/1875] | Batch Loss: 2.4669
# Epoch [4/20] | Batch [600/1875] | Batch Loss: 1.9950
# Epoch [4/20] | Batch [700/1875] | Batch Loss: 2.3657
# Epoch [4/20] | Batch [800/1875] | Batch Loss: 1.9348
# Epoch [4/20] | Batch [900/1875] | Batch Loss: 1.7838
# Epoch [4/20] | Batch [1000/1875] | Batch Loss: 2.3561
# Epoch [4/20] | Batch [1100/1875] | Batch Loss: 2.1424
# Epoch [4/20] | Batch [1200/1875] | Batch Loss: 2.1439
# Epoch [4/20] | Batch [1300/1875] | Batch Loss: 2.1654
# Epoch [4/20] | Batch [1400/1875] | Batch Loss: 2.0840
# Epoch [4/20] | Batch [1500/1875] | Batch Loss: 2.1267
# Epoch [4/20] | Batch [1600/1875] | Batch Loss: 1.9062
# Epoch [4/20] | Batch [1700/1875] | Batch Loss: 2.1631
# Epoch [4/20] | Batch [1800/1875] | Batch Loss: 2.2068
# ======================================
# Epoch [4/20] zakończona
# Train Loss     : 2.1288
# Train Accuracy : 57.37%
# Val Loss       : 2.1994
# Val Accuracy   : 55.16%
# Learning Rate  : 0.0452254248593737
# ======================================
# Najlepszy model zapisany.
# Epoch [5/20] | Batch [100/1875] | Batch Loss: 2.3507
# Epoch [5/20] | Batch [200/1875] | Batch Loss: 2.1364
# Epoch [5/20] | Batch [300/1875] | Batch Loss: 2.1450
# Epoch [5/20] | Batch [400/1875] | Batch Loss: 1.8435
# Epoch [5/20] | Batch [500/1875] | Batch Loss: 2.2091
# Epoch [5/20] | Batch [600/1875] | Batch Loss: 2.0603
# Epoch [5/20] | Batch [700/1875] | Batch Loss: 2.0355
# Epoch [5/20] | Batch [800/1875] | Batch Loss: 2.2753
# Epoch [5/20] | Batch [900/1875] | Batch Loss: 1.8128
# Epoch [5/20] | Batch [1000/1875] | Batch Loss: 2.0222
# Epoch [5/20] | Batch [1100/1875] | Batch Loss: 2.1086
# Epoch [5/20] | Batch [1200/1875] | Batch Loss: 1.9159
# Epoch [5/20] | Batch [1300/1875] | Batch Loss: 2.3534
# Epoch [5/20] | Batch [1400/1875] | Batch Loss: 2.0339
# Epoch [5/20] | Batch [1500/1875] | Batch Loss: 1.8678
# Epoch [5/20] | Batch [1600/1875] | Batch Loss: 2.1599
# Epoch [5/20] | Batch [1700/1875] | Batch Loss: 2.0689
# Epoch [5/20] | Batch [1800/1875] | Batch Loss: 1.9386
# ======================================
# Epoch [5/20] zakończona
# Train Loss     : 2.0382
# Train Accuracy : 60.23%
# Val Loss       : 2.1253
# Val Accuracy   : 56.79%
# Learning Rate  : 0.042677669529663696
# ======================================
# Najlepszy model zapisany.
# Epoch [6/20] | Batch [100/1875] | Batch Loss: 1.8516
# Epoch [6/20] | Batch [200/1875] | Batch Loss: 2.0479
# Epoch [6/20] | Batch [300/1875] | Batch Loss: 2.0246
# Epoch [6/20] | Batch [400/1875] | Batch Loss: 1.7718
# Epoch [6/20] | Batch [500/1875] | Batch Loss: 1.9378
# Epoch [6/20] | Batch [600/1875] | Batch Loss: 1.9216
# Epoch [6/20] | Batch [700/1875] | Batch Loss: 1.8582
# Epoch [6/20] | Batch [800/1875] | Batch Loss: 2.4173
# Epoch [6/20] | Batch [900/1875] | Batch Loss: 1.8658
# Epoch [6/20] | Batch [1000/1875] | Batch Loss: 1.8860
# Epoch [6/20] | Batch [1100/1875] | Batch Loss: 1.8921
# Epoch [6/20] | Batch [1200/1875] | Batch Loss: 1.9464
# Epoch [6/20] | Batch [1300/1875] | Batch Loss: 1.9496
# Epoch [6/20] | Batch [1400/1875] | Batch Loss: 2.0679
# Epoch [6/20] | Batch [1500/1875] | Batch Loss: 2.1171
# Epoch [6/20] | Batch [1600/1875] | Batch Loss: 2.0589
# Epoch [6/20] | Batch [1700/1875] | Batch Loss: 2.0274
# Epoch [6/20] | Batch [1800/1875] | Batch Loss: 1.8403
# ======================================
# Epoch [6/20] zakończona
# Train Loss     : 1.9646
# Train Accuracy : 62.45%
# Val Loss       : 2.0192
# Val Accuracy   : 60.33%
# Learning Rate  : 0.03969463130731184
# ======================================
# Najlepszy model zapisany.
# Epoch [7/20] | Batch [100/1875] | Batch Loss: 1.9931
# Epoch [7/20] | Batch [200/1875] | Batch Loss: 1.9362
# Epoch [7/20] | Batch [300/1875] | Batch Loss: 1.9003
# Epoch [7/20] | Batch [400/1875] | Batch Loss: 1.8773
# Epoch [7/20] | Batch [500/1875] | Batch Loss: 1.8119
# Epoch [7/20] | Batch [600/1875] | Batch Loss: 1.9548
# Epoch [7/20] | Batch [700/1875] | Batch Loss: 1.7870
# Epoch [7/20] | Batch [800/1875] | Batch Loss: 1.6508
# Epoch [7/20] | Batch [900/1875] | Batch Loss: 1.9348
# Epoch [7/20] | Batch [1000/1875] | Batch Loss: 1.8531
# Epoch [7/20] | Batch [1100/1875] | Batch Loss: 1.8418
# Epoch [7/20] | Batch [1200/1875] | Batch Loss: 1.8549
# Epoch [7/20] | Batch [1300/1875] | Batch Loss: 1.9767
# Epoch [7/20] | Batch [1400/1875] | Batch Loss: 1.6917
# Epoch [7/20] | Batch [1500/1875] | Batch Loss: 2.0230
# Epoch [7/20] | Batch [1600/1875] | Batch Loss: 1.6630
# Epoch [7/20] | Batch [1700/1875] | Batch Loss: 1.9438
# Epoch [7/20] | Batch [1800/1875] | Batch Loss: 2.1237
# ======================================
# Epoch [7/20] zakończona
# Train Loss     : 1.8999
# Train Accuracy : 64.56%
# Val Loss       : 1.9479
# Val Accuracy   : 61.74%
# Learning Rate  : 0.036349762493488674
# ======================================
# Najlepszy model zapisany.
# Epoch [8/20] | Batch [100/1875] | Batch Loss: 1.6743
# Epoch [8/20] | Batch [200/1875] | Batch Loss: 1.6859
# Epoch [8/20] | Batch [300/1875] | Batch Loss: 1.7103
# Epoch [8/20] | Batch [400/1875] | Batch Loss: 1.8004
# Epoch [8/20] | Batch [500/1875] | Batch Loss: 1.7532
# Epoch [8/20] | Batch [600/1875] | Batch Loss: 1.7642
# Epoch [8/20] | Batch [700/1875] | Batch Loss: 1.9902
# Epoch [8/20] | Batch [800/1875] | Batch Loss: 1.6941
# Epoch [8/20] | Batch [900/1875] | Batch Loss: 1.8686
# Epoch [8/20] | Batch [1000/1875] | Batch Loss: 1.9368
# Epoch [8/20] | Batch [1100/1875] | Batch Loss: 2.0687
# Epoch [8/20] | Batch [1200/1875] | Batch Loss: 1.8257
# Epoch [8/20] | Batch [1300/1875] | Batch Loss: 1.6780
# Epoch [8/20] | Batch [1400/1875] | Batch Loss: 1.8593
# Epoch [8/20] | Batch [1500/1875] | Batch Loss: 1.8815
# Epoch [8/20] | Batch [1600/1875] | Batch Loss: 1.5636
# Epoch [8/20] | Batch [1700/1875] | Batch Loss: 1.9634
# Epoch [8/20] | Batch [1800/1875] | Batch Loss: 1.7724
# ======================================
# Epoch [8/20] zakończona
# Train Loss     : 1.8362
# Train Accuracy : 66.55%
# Val Loss       : 1.8882
# Val Accuracy   : 64.41%
# Learning Rate  : 0.03272542485937369
# ======================================
# Najlepszy model zapisany.
# Epoch [9/20] | Batch [100/1875] | Batch Loss: 2.0469
# Epoch [9/20] | Batch [200/1875] | Batch Loss: 1.7791
# Epoch [9/20] | Batch [300/1875] | Batch Loss: 1.6743
# Epoch [9/20] | Batch [400/1875] | Batch Loss: 1.6701
# Epoch [9/20] | Batch [500/1875] | Batch Loss: 1.4836
# Epoch [9/20] | Batch [600/1875] | Batch Loss: 1.6524
# Epoch [9/20] | Batch [700/1875] | Batch Loss: 1.7813
# Epoch [9/20] | Batch [800/1875] | Batch Loss: 1.7270
# Epoch [9/20] | Batch [900/1875] | Batch Loss: 1.8459
# Epoch [9/20] | Batch [1000/1875] | Batch Loss: 1.8391
# Epoch [9/20] | Batch [1100/1875] | Batch Loss: 1.6097
# Epoch [9/20] | Batch [1200/1875] | Batch Loss: 1.5622
# Epoch [9/20] | Batch [1300/1875] | Batch Loss: 1.7673
# Epoch [9/20] | Batch [1400/1875] | Batch Loss: 2.1259
# Epoch [9/20] | Batch [1500/1875] | Batch Loss: 1.7266
# Epoch [9/20] | Batch [1600/1875] | Batch Loss: 1.7642
# Epoch [9/20] | Batch [1700/1875] | Batch Loss: 1.8941
# Epoch [9/20] | Batch [1800/1875] | Batch Loss: 2.0192
# ======================================
# Epoch [9/20] zakończona
# Train Loss     : 1.7655
# Train Accuracy : 68.74%
# Val Loss       : 1.8545
# Val Accuracy   : 65.46%
# Learning Rate  : 0.02891086162600578
# ======================================
# Najlepszy model zapisany.
# Epoch [10/20] | Batch [100/1875] | Batch Loss: 1.5137
# Epoch [10/20] | Batch [200/1875] | Batch Loss: 1.8120
# Epoch [10/20] | Batch [300/1875] | Batch Loss: 1.5212
# Epoch [10/20] | Batch [400/1875] | Batch Loss: 1.7339
# Epoch [10/20] | Batch [500/1875] | Batch Loss: 1.6255
# Epoch [10/20] | Batch [600/1875] | Batch Loss: 1.6725
# Epoch [10/20] | Batch [700/1875] | Batch Loss: 1.6531
# Epoch [10/20] | Batch [800/1875] | Batch Loss: 2.0952
# Epoch [10/20] | Batch [900/1875] | Batch Loss: 1.6493
# Epoch [10/20] | Batch [1000/1875] | Batch Loss: 1.6808
# Epoch [10/20] | Batch [1100/1875] | Batch Loss: 1.6992
# Epoch [10/20] | Batch [1200/1875] | Batch Loss: 1.5885
# Epoch [10/20] | Batch [1300/1875] | Batch Loss: 1.7086
# Epoch [10/20] | Batch [1400/1875] | Batch Loss: 1.6584
# Epoch [10/20] | Batch [1500/1875] | Batch Loss: 1.6195
# Epoch [10/20] | Batch [1600/1875] | Batch Loss: 1.7368
# Epoch [10/20] | Batch [1700/1875] | Batch Loss: 1.6728
# Epoch [10/20] | Batch [1800/1875] | Batch Loss: 1.7073
# ======================================
# Epoch [10/20] zakończona
# Train Loss     : 1.6972
# Train Accuracy : 70.92%
# Val Loss       : 1.7740
# Val Accuracy   : 68.10%
# Learning Rate  : 0.025000000000000005
# ======================================
# Najlepszy model zapisany.
# Epoch [11/20] | Batch [100/1875] | Batch Loss: 1.7076
# Epoch [11/20] | Batch [200/1875] | Batch Loss: 1.6340
# Epoch [11/20] | Batch [300/1875] | Batch Loss: 1.4544
# Epoch [11/20] | Batch [400/1875] | Batch Loss: 1.6067
# Epoch [11/20] | Batch [500/1875] | Batch Loss: 1.6311
# Epoch [11/20] | Batch [600/1875] | Batch Loss: 1.6177
# Epoch [11/20] | Batch [700/1875] | Batch Loss: 1.4656
# Epoch [11/20] | Batch [800/1875] | Batch Loss: 1.5796
# Epoch [11/20] | Batch [900/1875] | Batch Loss: 1.5745
# Epoch [11/20] | Batch [1000/1875] | Batch Loss: 1.6112
# Epoch [11/20] | Batch [1100/1875] | Batch Loss: 1.8231
# Epoch [11/20] | Batch [1200/1875] | Batch Loss: 1.7171
# Epoch [11/20] | Batch [1300/1875] | Batch Loss: 1.8298
# Epoch [11/20] | Batch [1400/1875] | Batch Loss: 1.6447
# Epoch [11/20] | Batch [1500/1875] | Batch Loss: 1.7043
# Epoch [11/20] | Batch [1600/1875] | Batch Loss: 1.6021
# Epoch [11/20] | Batch [1700/1875] | Batch Loss: 1.4938
# Epoch [11/20] | Batch [1800/1875] | Batch Loss: 1.6352
# ======================================
# Epoch [11/20] zakończona
# Train Loss     : 1.6209
# Train Accuracy : 73.28%
# Val Loss       : 1.7174
# Val Accuracy   : 69.54%
# Learning Rate  : 0.02108913837399424
# ======================================
# Najlepszy model zapisany.
# Epoch [12/20] | Batch [100/1875] | Batch Loss: 1.6815
# Epoch [12/20] | Batch [200/1875] | Batch Loss: 1.4054
# Epoch [12/20] | Batch [300/1875] | Batch Loss: 1.2577
# Epoch [12/20] | Batch [400/1875] | Batch Loss: 1.6502
# Epoch [12/20] | Batch [500/1875] | Batch Loss: 1.3675
# Epoch [12/20] | Batch [600/1875] | Batch Loss: 1.5562
# Epoch [12/20] | Batch [700/1875] | Batch Loss: 1.4985
# Epoch [12/20] | Batch [800/1875] | Batch Loss: 1.6024
# Epoch [12/20] | Batch [900/1875] | Batch Loss: 1.5336
# Epoch [12/20] | Batch [1000/1875] | Batch Loss: 1.7490
# Epoch [12/20] | Batch [1100/1875] | Batch Loss: 1.5757
# Epoch [12/20] | Batch [1200/1875] | Batch Loss: 1.4915
# Epoch [12/20] | Batch [1300/1875] | Batch Loss: 1.4371
# Epoch [12/20] | Batch [1400/1875] | Batch Loss: 1.7091
# Epoch [12/20] | Batch [1500/1875] | Batch Loss: 1.5313
# Epoch [12/20] | Batch [1600/1875] | Batch Loss: 1.5857
# Epoch [12/20] | Batch [1700/1875] | Batch Loss: 1.6213
# Epoch [12/20] | Batch [1800/1875] | Batch Loss: 1.7779
# ======================================
# Epoch [12/20] zakończona
# Train Loss     : 1.5420
# Train Accuracy : 75.87%
# Val Loss       : 1.6558
# Val Accuracy   : 71.23%
# Learning Rate  : 0.01727457514062632
# ======================================
# Najlepszy model zapisany.
# Epoch [13/20] | Batch [100/1875] | Batch Loss: 1.4337
# Epoch [13/20] | Batch [200/1875] | Batch Loss: 1.4499
# Epoch [13/20] | Batch [300/1875] | Batch Loss: 1.5383
# Epoch [13/20] | Batch [400/1875] | Batch Loss: 1.3357
# Epoch [13/20] | Batch [500/1875] | Batch Loss: 1.4414
# Epoch [13/20] | Batch [600/1875] | Batch Loss: 1.3394
# Epoch [13/20] | Batch [700/1875] | Batch Loss: 1.4685
# Epoch [13/20] | Batch [800/1875] | Batch Loss: 1.6850
# Epoch [13/20] | Batch [900/1875] | Batch Loss: 1.3542
# Epoch [13/20] | Batch [1000/1875] | Batch Loss: 1.4523
# Epoch [13/20] | Batch [1100/1875] | Batch Loss: 1.3242
# Epoch [13/20] | Batch [1200/1875] | Batch Loss: 1.3836
# Epoch [13/20] | Batch [1300/1875] | Batch Loss: 1.3360
# Epoch [13/20] | Batch [1400/1875] | Batch Loss: 1.4862
# Epoch [13/20] | Batch [1500/1875] | Batch Loss: 1.4438
# Epoch [13/20] | Batch [1600/1875] | Batch Loss: 1.4370
# Epoch [13/20] | Batch [1700/1875] | Batch Loss: 1.2514
# Epoch [13/20] | Batch [1800/1875] | Batch Loss: 1.6297
# ======================================
# Epoch [13/20] zakończona
# Train Loss     : 1.4588
# Train Accuracy : 78.68%
# Val Loss       : 1.5543
# Val Accuracy   : 74.57%
# Learning Rate  : 0.013650237506511334
# ======================================
# Najlepszy model zapisany.
# Epoch [14/20] | Batch [100/1875] | Batch Loss: 1.3380
# Epoch [14/20] | Batch [200/1875] | Batch Loss: 1.4475
# Epoch [14/20] | Batch [300/1875] | Batch Loss: 1.2534
# Epoch [14/20] | Batch [400/1875] | Batch Loss: 1.3124
# Epoch [14/20] | Batch [500/1875] | Batch Loss: 1.3955
# Epoch [14/20] | Batch [600/1875] | Batch Loss: 1.3602
# Epoch [14/20] | Batch [700/1875] | Batch Loss: 1.3583
# Epoch [14/20] | Batch [800/1875] | Batch Loss: 1.3564
# Epoch [14/20] | Batch [900/1875] | Batch Loss: 1.3989
# Epoch [14/20] | Batch [1000/1875] | Batch Loss: 1.3023
# Epoch [14/20] | Batch [1100/1875] | Batch Loss: 1.2446
# Epoch [14/20] | Batch [1200/1875] | Batch Loss: 1.5126
# Epoch [14/20] | Batch [1300/1875] | Batch Loss: 1.3968
# Epoch [14/20] | Batch [1400/1875] | Batch Loss: 1.5270
# Epoch [14/20] | Batch [1500/1875] | Batch Loss: 1.2506
# Epoch [14/20] | Batch [1600/1875] | Batch Loss: 1.4054
# Epoch [14/20] | Batch [1700/1875] | Batch Loss: 1.1741
# Epoch [14/20] | Batch [1800/1875] | Batch Loss: 1.4768
# ======================================
# Epoch [14/20] zakończona
# Train Loss     : 1.3666
# Train Accuracy : 81.66%
# Val Loss       : 1.4592
# Val Accuracy   : 77.60%
# Learning Rate  : 0.010305368692688176
# ======================================
# Najlepszy model zapisany.
# Epoch [15/20] | Batch [100/1875] | Batch Loss: 1.2917
# Epoch [15/20] | Batch [200/1875] | Batch Loss: 1.1871
# Epoch [15/20] | Batch [300/1875] | Batch Loss: 1.3408
# Epoch [15/20] | Batch [400/1875] | Batch Loss: 1.2747
# Epoch [15/20] | Batch [500/1875] | Batch Loss: 1.2227
# Epoch [15/20] | Batch [600/1875] | Batch Loss: 1.1465
# Epoch [15/20] | Batch [700/1875] | Batch Loss: 1.1633
# Epoch [15/20] | Batch [800/1875] | Batch Loss: 1.2141
# Epoch [15/20] | Batch [900/1875] | Batch Loss: 1.2685
# Epoch [15/20] | Batch [1000/1875] | Batch Loss: 1.1205
# Epoch [15/20] | Batch [1100/1875] | Batch Loss: 1.4805
# Epoch [15/20] | Batch [1200/1875] | Batch Loss: 1.3709
# Epoch [15/20] | Batch [1300/1875] | Batch Loss: 1.3715
# Epoch [15/20] | Batch [1400/1875] | Batch Loss: 1.2017
# Epoch [15/20] | Batch [1500/1875] | Batch Loss: 1.2636
# Epoch [15/20] | Batch [1600/1875] | Batch Loss: 1.4475
# Epoch [15/20] | Batch [1700/1875] | Batch Loss: 1.2810
# Epoch [15/20] | Batch [1800/1875] | Batch Loss: 1.4221
# ======================================
# Epoch [15/20] zakończona
# Train Loss     : 1.2694
# Train Accuracy : 84.90%
# Val Loss       : 1.3533
# Val Accuracy   : 81.11%
# Learning Rate  : 0.007322330470336314
# ======================================
# Najlepszy model zapisany.
# Epoch [16/20] | Batch [100/1875] | Batch Loss: 1.0719
# Epoch [16/20] | Batch [200/1875] | Batch Loss: 1.0940
# Epoch [16/20] | Batch [300/1875] | Batch Loss: 1.1121
# Epoch [16/20] | Batch [400/1875] | Batch Loss: 1.1362
# Epoch [16/20] | Batch [500/1875] | Batch Loss: 1.0526
# Epoch [16/20] | Batch [600/1875] | Batch Loss: 1.2250
# Epoch [16/20] | Batch [700/1875] | Batch Loss: 1.1978
# Epoch [16/20] | Batch [800/1875] | Batch Loss: 1.1142
# Epoch [16/20] | Batch [900/1875] | Batch Loss: 1.1564
# Epoch [16/20] | Batch [1000/1875] | Batch Loss: 1.1266
# Epoch [16/20] | Batch [1100/1875] | Batch Loss: 1.1255
# Epoch [16/20] | Batch [1200/1875] | Batch Loss: 1.1082
# Epoch [16/20] | Batch [1300/1875] | Batch Loss: 1.2583
# Epoch [16/20] | Batch [1400/1875] | Batch Loss: 1.1437
# Epoch [16/20] | Batch [1500/1875] | Batch Loss: 1.0518
# Epoch [16/20] | Batch [1600/1875] | Batch Loss: 1.2615
# Epoch [16/20] | Batch [1700/1875] | Batch Loss: 1.1261
# Epoch [16/20] | Batch [1800/1875] | Batch Loss: 1.2978
# ======================================
# Epoch [16/20] zakończona
# Train Loss     : 1.1638
# Train Accuracy : 88.57%
# Val Loss       : 1.2475
# Val Accuracy   : 84.63%
# Learning Rate  : 0.004774575140626317
# ======================================
# Najlepszy model zapisany.
# Epoch [17/20] | Batch [100/1875] | Batch Loss: 0.9334
# Epoch [17/20] | Batch [200/1875] | Batch Loss: 0.9955
# Epoch [17/20] | Batch [300/1875] | Batch Loss: 1.1407
# Epoch [17/20] | Batch [400/1875] | Batch Loss: 1.0557
# Epoch [17/20] | Batch [500/1875] | Batch Loss: 1.1361
# Epoch [17/20] | Batch [600/1875] | Batch Loss: 1.0191
# Epoch [17/20] | Batch [700/1875] | Batch Loss: 1.0368
# Epoch [17/20] | Batch [800/1875] | Batch Loss: 1.1029
# Epoch [17/20] | Batch [900/1875] | Batch Loss: 1.2137
# Epoch [17/20] | Batch [1000/1875] | Batch Loss: 1.0993
# Epoch [17/20] | Batch [1100/1875] | Batch Loss: 1.0671
# Epoch [17/20] | Batch [1200/1875] | Batch Loss: 1.1000
# Epoch [17/20] | Batch [1300/1875] | Batch Loss: 1.1594
# Epoch [17/20] | Batch [1400/1875] | Batch Loss: 1.0756
# Epoch [17/20] | Batch [1500/1875] | Batch Loss: 0.9636
# Epoch [17/20] | Batch [1600/1875] | Batch Loss: 0.9772
# Epoch [17/20] | Batch [1700/1875] | Batch Loss: 0.9780
# Epoch [17/20] | Batch [1800/1875] | Batch Loss: 1.1088
# ======================================
# Epoch [17/20] zakończona
# Train Loss     : 1.0739
# Train Accuracy : 91.62%
# Val Loss       : 1.1145
# Val Accuracy   : 89.22%
# Learning Rate  : 0.0027248368952908055
# ======================================
# Najlepszy model zapisany.
# Epoch [18/20] | Batch [100/1875] | Batch Loss: 1.0312
# Epoch [18/20] | Batch [200/1875] | Batch Loss: 1.0085
# Epoch [18/20] | Batch [300/1875] | Batch Loss: 0.9986
# Epoch [18/20] | Batch [400/1875] | Batch Loss: 0.9927
# Epoch [18/20] | Batch [500/1875] | Batch Loss: 1.0018
# Epoch [18/20] | Batch [600/1875] | Batch Loss: 0.9897
# Epoch [18/20] | Batch [700/1875] | Batch Loss: 0.9740
# Epoch [18/20] | Batch [800/1875] | Batch Loss: 0.9216
# Epoch [18/20] | Batch [900/1875] | Batch Loss: 0.9446
# Epoch [18/20] | Batch [1000/1875] | Batch Loss: 0.9491
# Epoch [18/20] | Batch [1100/1875] | Batch Loss: 0.9467
# Epoch [18/20] | Batch [1200/1875] | Batch Loss: 0.8751
# Epoch [18/20] | Batch [1300/1875] | Batch Loss: 0.8861
# Epoch [18/20] | Batch [1400/1875] | Batch Loss: 0.9963
# Epoch [18/20] | Batch [1500/1875] | Batch Loss: 0.9642
# Epoch [18/20] | Batch [1600/1875] | Batch Loss: 1.0357
# Epoch [18/20] | Batch [1700/1875] | Batch Loss: 1.0528
# Epoch [18/20] | Batch [1800/1875] | Batch Loss: 1.1312
# ======================================
# Epoch [18/20] zakończona
# Train Loss     : 0.9882
# Train Accuracy : 94.59%
# Val Loss       : 1.0386
# Val Accuracy   : 91.74%
# Learning Rate  : 0.0012235870926211618
# ======================================
# Najlepszy model zapisany.
# Epoch [19/20] | Batch [100/1875] | Batch Loss: 0.8907
# Epoch [19/20] | Batch [200/1875] | Batch Loss: 0.9347
# Epoch [19/20] | Batch [300/1875] | Batch Loss: 0.9124
# Epoch [19/20] | Batch [400/1875] | Batch Loss: 0.9676
# Epoch [19/20] | Batch [500/1875] | Batch Loss: 0.8734
# Epoch [19/20] | Batch [600/1875] | Batch Loss: 0.9221
# Epoch [19/20] | Batch [700/1875] | Batch Loss: 0.9618
# Epoch [19/20] | Batch [800/1875] | Batch Loss: 0.9901
# Epoch [19/20] | Batch [900/1875] | Batch Loss: 0.8598
# Epoch [19/20] | Batch [1000/1875] | Batch Loss: 0.8531
# Epoch [19/20] | Batch [1100/1875] | Batch Loss: 1.0294
# Epoch [19/20] | Batch [1200/1875] | Batch Loss: 1.0097
# Epoch [19/20] | Batch [1300/1875] | Batch Loss: 0.9129
# Epoch [19/20] | Batch [1400/1875] | Batch Loss: 0.8816
# Epoch [19/20] | Batch [1500/1875] | Batch Loss: 0.9387
# Epoch [19/20] | Batch [1600/1875] | Batch Loss: 0.8868
# Epoch [19/20] | Batch [1700/1875] | Batch Loss: 0.9100
# Epoch [19/20] | Batch [1800/1875] | Batch Loss: 0.8690
# ======================================
# Epoch [19/20] zakończona
# Train Loss     : 0.9297
# Train Accuracy : 96.49%
# Val Loss       : 0.9883
# Val Accuracy   : 93.56%
# Learning Rate  : 0.00030779148512155856
# ======================================
# Najlepszy model zapisany.
# Epoch [20/20] | Batch [100/1875] | Batch Loss: 0.9810
# Epoch [20/20] | Batch [200/1875] | Batch Loss: 0.8456
# Epoch [20/20] | Batch [300/1875] | Batch Loss: 0.8827
# Epoch [20/20] | Batch [400/1875] | Batch Loss: 0.8618
# Epoch [20/20] | Batch [500/1875] | Batch Loss: 1.0184
# Epoch [20/20] | Batch [600/1875] | Batch Loss: 0.8433
# Epoch [20/20] | Batch [700/1875] | Batch Loss: 0.8593
# Epoch [20/20] | Batch [800/1875] | Batch Loss: 0.8459
# Epoch [20/20] | Batch [900/1875] | Batch Loss: 0.8344
# Epoch [20/20] | Batch [1000/1875] | Batch Loss: 0.8825
# Epoch [20/20] | Batch [1100/1875] | Batch Loss: 0.9918
# Epoch [20/20] | Batch [1200/1875] | Batch Loss: 0.9765
# Epoch [20/20] | Batch [1300/1875] | Batch Loss: 0.9413
# Epoch [20/20] | Batch [1400/1875] | Batch Loss: 0.9322
# Epoch [20/20] | Batch [1500/1875] | Batch Loss: 0.9506
# Epoch [20/20] | Batch [1600/1875] | Batch Loss: 0.9142
# Epoch [20/20] | Batch [1700/1875] | Batch Loss: 0.8556
# Epoch [20/20] | Batch [1800/1875] | Batch Loss: 0.9068
# ======================================
# Epoch [20/20] zakończona
# Train Loss     : 0.9034
# Train Accuracy : 97.40%
# Val Loss       : 0.9657
# Val Accuracy   : 94.45%
# Learning Rate  : 0.0
# ======================================
# Najlepszy model zapisany.
# ======================================
# KONIEC TRENINGU
# ======================================
# DenseNet(
#   (features): Sequential(
#     (conv0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu0): ReLU(inplace=True)
#     (pool0): Identity()
#     (denseblock1): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition1): _Transition(
#       (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock2): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition2): _Transition(
#       (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock3): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer17): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer18): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer19): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer20): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer21): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer22): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer23): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer24): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition3): _Transition(
#       (norm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock4): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (norm5): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.3, inplace=False)
#     (1): Linear(in_features=1024, out_features=100, bias=True)
#   )
# )

# %%
# EWALUACJA


model.eval()

correct = 0
total = 0

with torch.no_grad():

    for images, labels in test_loader:

        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)

        _, predicted = torch.max(outputs.data, 1)

        total += labels.size(0)

        correct += (predicted == labels).sum().item()

accuracy = 100 * correct / total

print("======================================")
print(f"Accuracy: {accuracy:.2f}%")
print("======================================")
# Out:
# ======================================
# Accuracy: 77.74%
# ======================================

# %%
# ============================================================
# ZAPIS WYNIKÓW DO EXCELA
# ============================================================

from datetime import datetime
OPTIMIZER_NAME = "SGD"
SCHEDULER_NAME = "CosineAnnealingLR"
new_result = {
    
    
    "Timestamp": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
    "Dataset": DATASET_NAME,
    "Model": "Densenet121",
    "Batch Size": BATCH_SIZE,
    "Max Epochs": EPOCHS,
    "Executed Epochs": epoch + 1,
    "Learning Rate": LEARNING_RATE,
    "Patience": PATIENCE,
    "Optimizer": OPTIMIZER_NAME,
    "Scheduler": SCHEDULER_NAME,

    "Train Accuracy": round(train_accuracy, 2),
    "Validation Accuracy": round(val_accuracy, 2),
    "Test Accuracy": round(accuracy, 2),
    "Best Validation Loss": round(best_val_loss, 4),
    "Model Path": MODEL_SAVE_PATH,
    "Device": str(device)
}

# ============================================================
# ODCZYT ISTNIEJĄCEGO PLIKU
# ============================================================

if os.path.exists(RESULTS_TO_EXCEL):

    try:

        df_existing = pd.read_excel(RESULTS_TO_EXCEL)

        df_new = pd.concat(
            [df_existing, pd.DataFrame([new_result])],
            ignore_index=True
        )

    except Exception as e:

        print("Błąd odczytu Excela:", e)

        print("Tworzenie nowego pliku Excel...")

        df_new = pd.DataFrame([new_result])

else:

    df_new = pd.DataFrame([new_result])

# ============================================================
# ZAPIS EXCEL
# ============================================================

try:

    df_new.to_excel(RESULTS_TO_EXCEL, index=False)

    print("======================================")
    print(f"Wyniki zapisane do: {RESULTS_TO_EXCEL}")
    print("======================================")

except Exception as e:

    print("======================================")
    print("BŁĄD ZAPISU EXCEL")
    print(e)
    print("======================================")
# Out:
# ======================================
# Wyniki zapisane do: training_results_densenet_augumentacja.xlsx
# ======================================

# %%
# ============================================================
# ZAPIS MODELU
# ============================================================

checkpoint = {
    "epoch": epoch + 1,
    "model_state_dict": model.state_dict(),
    "optimizer_state_dict": optimizer.state_dict(),
    "scheduler_state_dict": scheduler.state_dict(),
    "best_val_loss": best_val_loss,
    "dataset": DATASET_NAME,
    "batch_size": BATCH_SIZE,
    "learning_rate": LEARNING_RATE,
}

torch.save(checkpoint, MODEL_SAVE_PATH_CHECKPOINT)

print("======================================")
print(f"Model zapisany do: {MODEL_SAVE_PATH_CHECKPOINT}")
print("======================================")
# Out:
# ======================================
# Model zapisany do: models/t_checkpoint_augumentacja_densenet_cifar100_64batch_20epochs_0.05lr.pth
# ======================================
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
